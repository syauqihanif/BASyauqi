# %%
import pandas as pd
import sqlite3
import numpy as np

connection = sqlite3.connect('D:/Akademik/Semester 7/TA 1/Example 1/airport-develop/airport-develop/resources/database/Airports.db')
query = 'select * from runways'
database = pd.read_sql_query(query, connection)

icao_code_list = database["airportICAO"].unique()
icao_code_list

OAData = pd.read_csv('D:\Akademik\BachelorArbeit\Data\OArunways.csv')

# %%
database.loc[(database["airportICAO"] == "EDDM")]
# Out:
#      airportICAO rwyIdent  rwyBearing  rwyTrueBearing  rwySlope  \
# 1136        EDDM      08L        81.0       83.431058  -0.13716
# 1137        EDDM      08R        81.0       83.433766  -0.12192
# 1138        EDDM      26L       261.0      263.433766   0.12192
# 1139        EDDM      26R       261.0      263.431058   0.13716
#
#       rwyThresElevation  rwyThresCrossHeight  rwyWidth   rwyLon     rwyLat  \
# 1136            451.836               15.400    60.676  11.7676  48.362801
# 1137            457.688               15.400    60.676  11.7510  48.340698
# 1138            452.760               16.940    60.676  11.8046  48.344799
# 1139            446.292               15.708    60.676  11.8212  48.366901
#
#       ...  gldslpFreq gldslpAngle gldslpIdent  llzLat  llzLon  llzElevation  \
# 1136  ...       109.5    3.000834        IMNE     NaN     NaN           NaN
# 1137  ...       109.3    3.000834        IMSE     NaN     NaN           NaN
# 1138  ...       108.3    3.002634        IMSW     NaN     NaN           NaN
# 1139  ...       108.7    3.002634        IMNW     NaN     NaN           NaN
#
#       llzFreq  llzBearing llzIdent llzCategory
# 1136      NaN         NaN     None        None
# 1137      NaN         NaN     None        None
# 1138      NaN         NaN     None        None
# 1139      NaN         NaN     None        None
#
# [4 rows x 33 columns]

# %%
rowOA = OAData.loc[(OAData["airport_ident"] =="EDDM")]

rowOA
# Out:
#            id  airport_ref airport_ident  length_ft  width_ft surface  \
# 15110  236229         2218          EDDM    13123.0     197.0     CON
# 15111  236228         2218          EDDM    13123.0     197.0     CON
#
#        lighted  closed le_ident  le_latitude_deg  le_longitude_deg  \
# 15110        1       0      08L        48.362801           11.7676
# 15111        1       0      08R        48.340698           11.7510
#
#        le_elevation_ft  le_heading_degT  le_displaced_threshold_ft he_ident  \
# 15110           1467.0             83.4                        NaN      26R
# 15111           1486.0             83.4                        NaN      26L
#
#        he_latitude_deg  he_longitude_deg  he_elevation_ft  he_heading_degT  \
# 15110        48.366901           11.8212           1449.0            263.4
# 15111        48.344799           11.8046           1470.0            263.4
#
#        he_displaced_threshold_ft
# 15110                        NaN
# 15111                        NaN

# %%
#print(OAData)
OAData.shape
# Out:
# (43893, 20)

# %%
ignored = "ZZZZ"
ignored = "EDDM"
from datetime import datetime

start = datetime.now()

if (database.loc[(database["airportICAO"] == ignored)].shape[0]) != 0:
    print("ADA")
else:
    print("TIDAK ADA")

print(datetime.now() - start)

database.loc[(database["airportICAO"] == ignored)].shape[0]
# Out:
# ADA
# 0:00:00.001995
# 4

# %%
index_name_list = []
dataframe_list = []
column_name_list = ["airportICAO","rwyIdent","rwyBearing", "rwyTrueBearing", "rwySlope", "rwyThresElevation", 
                    "rwyThresCrossHeight", "rwyWidth", "rwyLon", "rwyLat", "rwyLength",
                    "rwySurface", "rwyGlideslopeAngle", "ilsLat", "ilsLon", "ilsElevation",
                    "ilsFreq", "ilsBearing", "ilsIdent", "ilsCategory", "gldslpLat", "gldslpLon",
                    "gldslpElevation", "gldslpFreq", "gldslpAngle", "gldslpIdent", "llzLat", "llzLon",
                    "llzElevation", "llzFreq", "llzBearing", "llzIdent", "llzCategory"]


for row in OAData.itertuples():
    
    if (database.loc[(database["airportICAO"] == row.airport_ident)].shape[0]) != 0:
    
        #LE
        index_name = "{}/{}".format(row.airport_ident, row.le_ident)
        index_name_list.append(index_name) 

        data_list = []
        #1. airportICAO
        data_list.append(row.airport_ident)

        #1. rwyIdent
        data_list.append(row.le_ident)


        #1. RwyBearing
        data_list.append(np.nan)

        #2. RwyTrueBearing
        data_list.append(row.le_heading_degT)

        #3. RwySlope
        data_list.append(np.nan)

        #4. rwyThresElevation
        data_list.append(row.le_elevation_ft)

        #5. rwyThresCrossHeight
        data_list.append(np.nan)

        #6. rwyWidth
        data_list.append(row.width_ft)

        #7. rwyLon
        data_list.append(row.le_longitude_deg)

        #8. rwyLat
        data_list.append(row.le_latitude_deg)

        #9. rwyLength
        data_list.append(row.length_ft)

        #10. rwySurface
        data_list.append(row.surface)

        #11. rwyGlideslopeAngle
        data_list.append(np.nan)

        #12. ilsLat
        data_list.append(np.nan)

        #13. ilsLon
        data_list.append(np.nan)

        #14. ilsElevation
        data_list.append(np.nan)

        #15. ilsFreq
        data_list.append(np.nan)

        #15. ilsBearing
        data_list.append(np.nan)

        #16. ilsIdent
        data_list.append(np.nan)

        #17. ilsCategory
        data_list.append(np.nan)

        #18. gldslpLat
        data_list.append(np.nan)

        #19. gldslpLon
        data_list.append(np.nan)

        #20. gldslpElevation
        data_list.append(np.nan)

        #21. gldslpFreq
        data_list.append(np.nan)

        #22. gldslpAngle
        data_list.append(np.nan)

        #23. gldslpIdent
        data_list.append(np.nan)

        #24. llzLat
        data_list.append(np.nan)

        #25. llzLon
        data_list.append(np.nan)

        #26. llzElevation
        data_list.append(np.nan)

        #27. llzFreq
        data_list.append(np.nan)

        #28. llzBearing
        data_list.append(np.nan)

        #29. llzIdent
        data_list.append(np.nan)

        #30. llzCategory
        data_list.append(np.nan)


        dataframe_list.append(data_list)


        #HE
        index_name = "{}/{}".format(row.airport_ident, row.he_ident)
        index_name_list.append(index_name) 

        data_list = []
        #1. airportICAO
        data_list.append(row.airport_ident)

        #1. rwyIdent
        data_list.append(row.he_ident)


        #1. RwyBearing
        data_list.append(np.nan)

        #2. RwyTrueBearing
        data_list.append(row.he_heading_degT)

        #3. RwySlope
        data_list.append(np.nan)

        #4. rwyThresElevation
        data_list.append(row.he_elevation_ft)

        #5. rwyThresCrossHeight
        data_list.append(np.nan)

        #6. rwyWidth
        data_list.append(row.width_ft)

        #7. rwyLon
        data_list.append(row.he_longitude_deg)

        #8. rwyLat
        data_list.append(row.he_latitude_deg)

        #9. rwyLength
        data_list.append(row.length_ft)

        #10. rwySurface
        data_list.append(row.surface)

        #11. rwyGlideslopeAngle
        data_list.append(np.nan)

        #12. ilsLat
        data_list.append(np.nan)

        #13. ilsLon
        data_list.append(np.nan)

        #14. ilsElevation
        data_list.append(np.nan)

        #15. ilsFreq
        data_list.append(np.nan)

        #15. ilsBearing
        data_list.append(np.nan)

        #16. ilsIdent
        data_list.append(np.nan)

        #17. ilsCategory
        data_list.append(np.nan)

        #18. gldslpLat
        data_list.append(np.nan)

        #19. gldslpLon
        data_list.append(np.nan)

        #20. gldslpElevation
        data_list.append(np.nan)

        #21. gldslpFreq
        data_list.append(np.nan)

        #22. gldslpAngle
        data_list.append(np.nan)

        #23. gldslpIdent
        data_list.append(np.nan)

        #24. llzLat
        data_list.append(np.nan)

        #25. llzLon
        data_list.append(np.nan)

        #26. llzElevation
        data_list.append(np.nan)

        #27. llzFreq
        data_list.append(np.nan)

        #28. llzBearing
        data_list.append(np.nan)

        #29. llzIdent
        data_list.append(np.nan)

        #30. llzCategory
        data_list.append(np.nan)

        dataframe_list.append(data_list)
    
    else:
        pass

dataframe = pd.DataFrame(index=index_name_list, data=dataframe_list, columns=column_name_list)
dataframe
# Out:
#         airportICAO rwyIdent  rwyBearing  rwyTrueBearing  rwySlope  \
# AGGH/06        AGGH       06         NaN            68.0       NaN
# AGGH/24        AGGH       24         NaN           248.0       NaN
# ANYN/12        ANYN       12         NaN           121.0       NaN
# ANYN/30        ANYN       30         NaN           301.0       NaN
# AYBK/04        AYBK       04         NaN            48.0       NaN
# ...             ...      ...         ...             ...       ...
# ZYTL/28        ZYTL       28         NaN           275.6       NaN
# ZYTX/06        ZYTX       06         NaN            49.0       NaN
# ZYTX/24        ZYTX       24         NaN           229.0       NaN
# ZYYJ/09        ZYYJ       09         NaN            81.7       NaN
# ZYYJ/27        ZYYJ       27         NaN           261.7       NaN
#
#          rwyThresElevation  rwyThresCrossHeight  rwyWidth      rwyLon  \
# AGGH/06               28.0                  NaN     148.0  160.044998
# AGGH/24               14.0                  NaN     148.0  160.063995
# ANYN/12               22.0                  NaN     148.0  166.912003
# ANYN/30               20.0                  NaN     148.0  166.925995
# AYBK/04               11.0                  NaN      98.0  154.667007
# ...                    ...                  ...       ...         ...
# ZYTL/28               85.0                  NaN     148.0  121.557999
# ZYTX/06              171.0                  NaN     148.0  123.469002
# ZYTX/24              197.0                  NaN     148.0  123.498001
# ZYYJ/09              623.0                  NaN     148.0  129.436005
# ZYYJ/27              597.0                  NaN     148.0  129.466995
#
#             rwyLat  ...  gldslpFreq gldslpAngle  gldslpIdent  llzLat  llzLon  \
# AGGH/06  -9.431740  ...         NaN         NaN          NaN     NaN     NaN
# AGGH/24  -9.424260  ...         NaN         NaN          NaN     NaN     NaN
# ANYN/12  -0.541181  ...         NaN         NaN          NaN     NaN     NaN
# ANYN/30  -0.553739  ...         NaN         NaN          NaN     NaN     NaN
# AYBK/04  -5.427010  ...         NaN         NaN          NaN     NaN     NaN
# ...            ...  ...         ...         ...          ...     ...     ...
# ZYTL/28  38.964199  ...         NaN         NaN          NaN     NaN     NaN
# ZYTX/06  41.630402  ...         NaN         NaN          NaN     NaN     NaN
# ZYTX/24  41.649300  ...         NaN         NaN          NaN     NaN     NaN
# ZYYJ/09  42.881100  ...         NaN         NaN          NaN     NaN     NaN
# ZYYJ/27  42.884499  ...         NaN         NaN          NaN     NaN     NaN
#
#          llzElevation  llzFreq  llzBearing  llzIdent  llzCategory
# AGGH/06           NaN      NaN         NaN       NaN          NaN
# AGGH/24           NaN      NaN         NaN       NaN          NaN
# ANYN/12           NaN      NaN         NaN       NaN          NaN
# ANYN/30           NaN      NaN         NaN       NaN          NaN
# AYBK/04           NaN      NaN         NaN       NaN          NaN
# ...               ...      ...         ...       ...          ...
# ZYTL/28           NaN      NaN         NaN       NaN          NaN
# ZYTX/06           NaN      NaN         NaN       NaN          NaN
# ZYTX/24           NaN      NaN         NaN       NaN          NaN
# ZYYJ/09           NaN      NaN         NaN       NaN          NaN
# ZYYJ/27           NaN      NaN         NaN       NaN          NaN
#
# [12012 rows x 33 columns]

# %%
icao_code_list
# Out:
# array(['AGGH', 'ANYN', 'AYBK', ..., 'OTHH', 'OMDW', 'OTBD'], dtype=object)

# %%
database.iloc[:, 2:] = np.nan

rwy = lambda icao, ident: database.index[(database.airportICAO == icao) & (database.rwyIdent == ident)]

database
for row in database.head(4).itertuples():
    print(row.airportICAO)
# Out:
# AGGH
# AGGH
# ANYN
# ANYN

# %%
#OAData.itertuples():

OAData.loc[(OAData["airport_ident"] == "AGGH")]
# Out:
#            id  airport_ref airport_ident  length_ft  width_ft surface  \
# 10791  233754            3          AGGH     7218.0     148.0     ASP
#
#        lighted  closed le_ident  le_latitude_deg  le_longitude_deg  \
# 10791        1       0       06         -9.43174        160.044998
#
#        le_elevation_ft  le_heading_degT  le_displaced_threshold_ft he_ident  \
# 10791             28.0             68.0                        NaN       24
#
#        he_latitude_deg  he_longitude_deg  he_elevation_ft  he_heading_degT  \
# 10791         -9.42426        160.063995             14.0            248.0
#
#        he_displaced_threshold_ft
# 10791                        NaN

# %%
OAData.loc[(OAData["airport_ident"] == "ANYN")]
# Out:
#            id  airport_ref airport_ident  length_ft  width_ft surface  \
# 11020  237996            8          ANYN     7054.0     148.0     ASP
#
#        lighted  closed le_ident  le_latitude_deg  le_longitude_deg  \
# 11020        1       0       12        -0.541181        166.912003
#
#        le_elevation_ft  le_heading_degT  le_displaced_threshold_ft he_ident  \
# 11020             22.0            121.0                      165.0       30
#
#        he_latitude_deg  he_longitude_deg  he_elevation_ft  he_heading_degT  \
# 11020        -0.553739        166.925995             20.0            301.0
#
#        he_displaced_threshold_ft
# 11020                      380.0

# %%
OAData
# Out:
#            id  airport_ref airport_ident  length_ft  width_ft   surface  \
# 0      269408         6523           00A       80.0      80.0    ASPH-G
# 1      255155         6524          00AK     2500.0      70.0      GRVL
# 2      254165         6525          00AL     2300.0     200.0      TURF
# 3      270932         6526          00AR       40.0      40.0     GRASS
# 4      322128       322127          00AS     1450.0      60.0      Turf
# ...       ...          ...           ...        ...       ...       ...
# 43888  235186        27243          ZYTX    10499.0     148.0       CON
# 43889  235169        27244          ZYYJ     8530.0     148.0       CON
# 43890  354997       317861          ZYYK     8202.0       NaN       NaN
# 43891  346789       346788       ZZ-0003     1800.0      15.0      Turf
# 43892  313663       313629          ZZZZ     1713.0      82.0  concrete
#
#        lighted  closed le_ident  le_latitude_deg  le_longitude_deg  \
# 0            1       0       H1              NaN               NaN
# 1            0       0        N              NaN               NaN
# 2            0       0       01              NaN               NaN
# 3            0       0       H1              NaN               NaN
# 4            0       0        1              NaN               NaN
# ...        ...     ...      ...              ...               ...
# 43888        1       0       06        41.630402        123.469002
# 43889        1       0       09        42.881100        129.436005
# 43890        0       0       04              NaN               NaN
# 43891        0       0       15              NaN               NaN
# 43892        0       0       18        30.783501        130.272995
#
#        le_elevation_ft  le_heading_degT  le_displaced_threshold_ft he_ident  \
# 0                  NaN              NaN                        NaN      NaN
# 1                  NaN              NaN                        NaN        S
# 2                  NaN              NaN                        NaN       19
# 3                  NaN              NaN                        NaN       H1
# 4                  NaN              NaN                        NaN       19
# ...                ...              ...                        ...      ...
# 43888            171.0             49.0                        NaN       24
# 43889            623.0             81.7                        NaN       27
# 43890              NaN              NaN                        NaN       22
# 43891              NaN              NaN                        NaN       33
# 43892              NaN              NaN                        NaN       36
#
#        he_latitude_deg  he_longitude_deg  he_elevation_ft  he_heading_degT  \
# 0                  NaN               NaN              NaN              NaN
# 1                  NaN               NaN              NaN              NaN
# 2                  NaN               NaN              NaN              NaN
# 3                  NaN               NaN              NaN              NaN
# 4                  NaN               NaN              NaN              NaN
# ...                ...               ...              ...              ...
# 43888        41.649300        123.498001            197.0            229.0
# 43889        42.884499        129.466995            597.0            261.7
# 43890              NaN               NaN              NaN              NaN
# 43891              NaN               NaN              NaN              NaN
# 43892        30.778099        130.272995              NaN              NaN
#
#        he_displaced_threshold_ft
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 43888                        NaN
# 43889                        NaN
# 43890                        NaN
# 43891                        NaN
# 43892                        NaN
#
# [43893 rows x 20 columns]

# %%
rows = database.loc[(database["airportICAO"] == "EDDM")]

rows
# Out:
#      airportICAO rwyIdent  rwyBearing  rwyTrueBearing  rwySlope  \
# 1136        EDDM      08L         NaN             NaN       NaN
# 1137        EDDM      08R         NaN             NaN       NaN
# 1138        EDDM      26L         NaN             NaN       NaN
# 1139        EDDM      26R         NaN             NaN       NaN
#
#       rwyThresElevation  rwyThresCrossHeight  rwyWidth  rwyLon  rwyLat  ...  \
# 1136                NaN                  NaN       NaN     NaN     NaN  ...
# 1137                NaN                  NaN       NaN     NaN     NaN  ...
# 1138                NaN                  NaN       NaN     NaN     NaN  ...
# 1139                NaN                  NaN       NaN     NaN     NaN  ...
#
#       gldslpFreq  gldslpAngle  gldslpIdent  llzLat  llzLon  llzElevation  \
# 1136         NaN          NaN          NaN     NaN     NaN           NaN
# 1137         NaN          NaN          NaN     NaN     NaN           NaN
# 1138         NaN          NaN          NaN     NaN     NaN           NaN
# 1139         NaN          NaN          NaN     NaN     NaN           NaN
#
#       llzFreq  llzBearing  llzIdent  llzCategory
# 1136      NaN         NaN       NaN          NaN
# 1137      NaN         NaN       NaN          NaN
# 1138      NaN         NaN       NaN          NaN
# 1139      NaN         NaN       NaN          NaN
#
# [4 rows x 33 columns]

# %%
 for row in rows.itertuples():
    
    rowInOA = OAData.loc[(OAData["airport_ident"] == row.airportICAO)]
    if len(rowInOA.loc[(rowInOA["le_ident"] == row.rwyIdent)]["id"]):
        _id = (rowInOA.loc[(rowInOA["le_ident"] == row.rwyIdent)]["id"])
    else:
        _id = (rowInOA.loc[(rowInOA["he_ident"] == row.rwyIdent)]["id"])
    print("{} --- {}".format(str(row.Index), str(_id)))
    print("\n")
    #also mention the prefix (le or he) when distinguishing runway for each row
# Out:
# 1136 --- 15105    236229
# Name: id, dtype: int64
#
#
# 1137 --- 15106    236228
# Name: id, dtype: int64
#
#
# 1138 --- 15106    236228
# Name: id, dtype: int64
#
#
# 1139 --- 15105    236229
# Name: id, dtype: int64

# %%
clean_data = {}
for (runway, value) in clean_data.items():
        
    #Edit and store runway-ident
    if ('le_ident' in runway):
        runwayIdent = runway.split(' ')[1]
    else:
        runwayIdent = runway

    index = rwy(icao_code, runwayIdent)
            
    try:
        database.loc[index, 'rwyBearing'] = value['...']
    except:
        pass

    try: 
        database.loc[index, 'rwySlope'] = value['le_elevation_ft']
    except:
        pass

    try:
        database.loc[index, 'rwyThresElevation'] = value['End Elevation:']
    except:
        pass

    try:
        database.loc[index, 'rwyWidth'] = value['width_ft']
    except:
        pass

    try:
        database.loc[index, 'rwyLon'] = value['le_longitude_deg']
    except:
        pass

    try:
        database.loc[index, 'rwyLat'] = value['le_latitude_deg']
    except:
        pass

    try:
        database.loc[index, 'rwyLength'] = value['length_ft']
    except:
        pass

    try:
        database.loc[index, 'rwySurface'] = value['surface']
    except:
        pass

# %%
for row in OAData.itertuples():
    if row.airport_ident == airport_ICAO:
        #Ekstrakt data
    break
    print (row)
# Out:
#   File "<ipython-input-7-ee05e4a3da2f>", line 4
#     break
#     ^
# IndentationError: expected an indented block

# %%
database
# Out:
#       airportICAO rwyIdent  rwyBearing  rwyTrueBearing  rwySlope  \
# 0            AGGH       06         NaN             NaN       NaN
# 1            AGGH       24         NaN             NaN       NaN
# 2            ANYN       12         NaN             NaN       NaN
# 3            ANYN       30         NaN             NaN       NaN
# 4            AYBK       04         NaN             NaN       NaN
# ...           ...      ...         ...             ...       ...
# 10837        OMDW       30         NaN             NaN       NaN
# 10838        OTBD       15         NaN             NaN       NaN
# 10839        OTBD       33         NaN             NaN       NaN
# 10840        UNNT       16         NaN             NaN       NaN
# 10841        UNNT       34         NaN             NaN       NaN
#
#        rwyThresElevation  rwyThresCrossHeight  rwyWidth  rwyLon  rwyLat  ...  \
# 0                    NaN                  NaN       NaN     NaN     NaN  ...
# 1                    NaN                  NaN       NaN     NaN     NaN  ...
# 2                    NaN                  NaN       NaN     NaN     NaN  ...
# 3                    NaN                  NaN       NaN     NaN     NaN  ...
# 4                    NaN                  NaN       NaN     NaN     NaN  ...
# ...                  ...                  ...       ...     ...     ...  ...
# 10837                NaN                  NaN       NaN     NaN     NaN  ...
# 10838                NaN                  NaN       NaN     NaN     NaN  ...
# 10839                NaN                  NaN       NaN     NaN     NaN  ...
# 10840                NaN                  NaN       NaN     NaN     NaN  ...
# 10841                NaN                  NaN       NaN     NaN     NaN  ...
#
#        gldslpFreq  gldslpAngle  gldslpIdent  llzLat  llzLon  llzElevation  \
# 0             NaN          NaN          NaN     NaN     NaN           NaN
# 1             NaN          NaN          NaN     NaN     NaN           NaN
# 2             NaN          NaN          NaN     NaN     NaN           NaN
# 3             NaN          NaN          NaN     NaN     NaN           NaN
# 4             NaN          NaN          NaN     NaN     NaN           NaN
# ...           ...          ...          ...     ...     ...           ...
# 10837         NaN          NaN          NaN     NaN     NaN           NaN
# 10838         NaN          NaN          NaN     NaN     NaN           NaN
# 10839         NaN          NaN          NaN     NaN     NaN           NaN
# 10840         NaN          NaN          NaN     NaN     NaN           NaN
# 10841         NaN          NaN          NaN     NaN     NaN           NaN
#
#        llzFreq  llzBearing  llzIdent  llzCategory
# 0          NaN         NaN       NaN          NaN
# 1          NaN         NaN       NaN          NaN
# 2          NaN         NaN       NaN          NaN
# 3          NaN         NaN       NaN          NaN
# 4          NaN         NaN       NaN          NaN
# ...        ...         ...       ...          ...
# 10837      NaN         NaN       NaN          NaN
# 10838      NaN         NaN       NaN          NaN
# 10839      NaN         NaN       NaN          NaN
# 10840      NaN         NaN       NaN          NaN
# 10841      NaN         NaN       NaN          NaN
#
# [10842 rows x 33 columns]

# %% [raw]
# runwayIdent

# %%
rwy = lambda icao, ident: database.index[(database.airportICAO == icao) & (database.rwyIdent == ident)]

database
# Out:
#       airportICAO rwyIdent rwyBearing  rwyTrueBearing  rwySlope  \
# 0            AGGH       06         59       68.242264 -0.221670
# 1            AGGH       24        239      248.242264  0.221670
# 2            ANYN       12        121      129.267903 -0.028353
# 3            ANYN       30        301      309.267903  0.028353
# 4            AYBK       04         39       46.780566 -0.097561
# ...           ...      ...        ...             ...       ...
# 10837        OMDW       30        300      301.459592       NaN
# 10838        OTBD       15        156      158.125868       NaN
# 10839        OTBD       33        336      338.125868       NaN
# 10840        UNNT       16        161      170.047178 -0.047750
# 10841        UNNT       34        341      350.047178  0.047750
#
#        rwyThresElevation  rwyThresCrossHeight  rwyWidth      rwyLon  \
# 0                  9.240                 15.4    45.584  160.044998
# 1                  4.312                 15.4    45.584  160.063995
# 2                  6.776                 15.4    45.584  166.912003
# 3                  6.160                 15.4    45.584  166.925995
# 4                  3.388                 15.4    30.184  154.667999
# ...                  ...                  ...       ...         ...
# 10837            170.000                  NaN    60.000   55.180199
# 10838             32.000                  NaN       NaN   51.556499
# 10839             25.000                  NaN       NaN   51.573502
# 10840            104.000                  NaN    60.000   82.594261
# 10841            101.000                  NaN    60.000   82.604073
#
#           rwyLat  ...  gldslpFreq gldslpAngle gldslpIdent  llzLat  llzLon  \
# 0      -9.431740  ...         NaN         NaN        None     NaN     NaN
# 1      -9.424260  ...         NaN         NaN        None     NaN     NaN
# 2      -0.542303  ...         NaN         NaN        None     NaN     NaN
# 3      -0.553742  ...         NaN         NaN        None     NaN     NaN
# 4      -5.426920  ...         NaN         NaN        None     NaN     NaN
# ...          ...  ...         ...         ...         ...     ...     ...
# 10837  24.886000  ...         NaN         NaN        None     NaN     NaN
# 10838  25.280199  ...         NaN         NaN        None     NaN     NaN
# 10839  25.241899  ...         NaN         NaN        None     NaN     NaN
# 10840  55.049263  ...         NaN         3.0        None     NaN     NaN
# 10841  55.017220  ...         NaN         3.0        None     NaN     NaN
#
#        llzElevation  llzFreq  llzBearing llzIdent llzCategory
# 0               NaN      NaN         NaN     None        None
# 1               NaN      NaN         NaN     None        None
# 2               NaN      NaN         NaN     None        None
# 3               NaN      NaN         NaN     None        None
# 4               NaN      NaN         NaN     None        None
# ...             ...      ...         ...      ...         ...
# 10837           NaN      NaN         NaN     None        None
# 10838           NaN      NaN         NaN     None        None
# 10839           NaN      NaN         NaN     None        None
# 10840           NaN      NaN         NaN     None        None
# 10841           NaN      NaN         NaN     None        None
#
# [10842 rows x 33 columns]

# %%
database.loc[(database["airportICAO"] == "EDDM")]
# Out:
#      airportICAO rwyIdent rwyBearing  rwyTrueBearing  rwySlope  \
# 1136        EDDM      08L       TEST       83.431058  -0.13716
# 1137        EDDM      08R         81       83.433766  -0.12192
# 1138        EDDM      26L        261      263.433766   0.12192
# 1139        EDDM      26R        261      263.431058   0.13716
#
#       rwyThresElevation  rwyThresCrossHeight  rwyWidth   rwyLon     rwyLat  \
# 1136            451.836               15.400    60.676  11.7676  48.362801
# 1137            457.688               15.400    60.676  11.7510  48.340698
# 1138            452.760               16.940    60.676  11.8046  48.344799
# 1139            446.292               15.708    60.676  11.8212  48.366901
#
#       ...  gldslpFreq gldslpAngle gldslpIdent  llzLat  llzLon  llzElevation  \
# 1136  ...       109.5    3.000834        IMNE     NaN     NaN           NaN
# 1137  ...       109.3    3.000834        IMSE     NaN     NaN           NaN
# 1138  ...       108.3    3.002634        IMSW     NaN     NaN           NaN
# 1139  ...       108.7    3.002634        IMNW     NaN     NaN           NaN
#
#       llzFreq  llzBearing llzIdent llzCategory
# 1136      NaN         NaN     None        None
# 1137      NaN         NaN     None        None
# 1138      NaN         NaN     None        None
# 1139      NaN         NaN     None        None
#
# [4 rows x 33 columns]

# %%
database.loc[(database["airportICAO"] == "EDDM") & (database["rwyIdent"] == "08L"), "rwyBearing"] = "TEST"

# %%
database.loc[(database["airportICAO"] == "EDDM")]
# Out:
#      airportICAO rwyIdent rwyBearing rwyTrueBearing rwySlope  \
# 1137        EDDM      08R       TEST            NaN      NaN
# 1138        EDDM      26L       TEST            NaN      NaN
# 1139        EDDM      26R       TEST            NaN      NaN
#
#      rwyThresElevation rwyThresCrossHeight rwyWidth rwyLon rwyLat  ...  \
# 1137               NaN                 NaN      NaN    NaN    NaN  ...
# 1138               NaN                 NaN      NaN    NaN    NaN  ...
# 1139               NaN                 NaN      NaN    NaN    NaN  ...
#
#      gldslpFreq gldslpAngle gldslpIdent llzLat llzLon llzElevation llzFreq  \
# 1137        NaN         NaN         NaN    NaN    NaN          NaN     NaN
# 1138        NaN         NaN         NaN    NaN    NaN          NaN     NaN
# 1139        NaN         NaN         NaN    NaN    NaN          NaN     NaN
#
#      llzBearing llzIdent llzCategory
# 1137        NaN      NaN         NaN
# 1138        NaN      NaN         NaN
# 1139        NaN      NaN         NaN
#
# [3 rows x 33 columns]

# %%
old_dtypes = database.dtypes
database.iloc[:, 2:] = None
database = database.astype(old_dtypes)

rwy = lambda icao, ident: database.index[(database.airportICAO == icao) & (database.rwyIdent == ident)]
database
# Out:
#       airportICAO rwyIdent rwyBearing  rwyTrueBearing  rwySlope  \
# 0            AGGH       06       None             NaN       NaN
# 1            AGGH       24       None             NaN       NaN
# 2            ANYN       12       None             NaN       NaN
# 3            ANYN       30       None             NaN       NaN
# 4            AYBK       04       None             NaN       NaN
# ...           ...      ...        ...             ...       ...
# 10837        OMDW       30       None             NaN       NaN
# 10838        OTBD       15       None             NaN       NaN
# 10839        OTBD       33       None             NaN       NaN
# 10840        UNNT       16       None             NaN       NaN
# 10841        UNNT       34       None             NaN       NaN
#
#        rwyThresElevation  rwyThresCrossHeight  rwyWidth  rwyLon  rwyLat  ...  \
# 0                    NaN                  NaN       NaN     NaN     NaN  ...
# 1                    NaN                  NaN       NaN     NaN     NaN  ...
# 2                    NaN                  NaN       NaN     NaN     NaN  ...
# 3                    NaN                  NaN       NaN     NaN     NaN  ...
# 4                    NaN                  NaN       NaN     NaN     NaN  ...
# ...                  ...                  ...       ...     ...     ...  ...
# 10837                NaN                  NaN       NaN     NaN     NaN  ...
# 10838                NaN                  NaN       NaN     NaN     NaN  ...
# 10839                NaN                  NaN       NaN     NaN     NaN  ...
# 10840                NaN                  NaN       NaN     NaN     NaN  ...
# 10841                NaN                  NaN       NaN     NaN     NaN  ...
#
#        gldslpFreq gldslpAngle gldslpIdent  llzLat  llzLon  llzElevation  \
# 0             NaN         NaN        None     NaN     NaN           NaN
# 1             NaN         NaN        None     NaN     NaN           NaN
# 2             NaN         NaN        None     NaN     NaN           NaN
# 3             NaN         NaN        None     NaN     NaN           NaN
# 4             NaN         NaN        None     NaN     NaN           NaN
# ...           ...         ...         ...     ...     ...           ...
# 10837         NaN         NaN        None     NaN     NaN           NaN
# 10838         NaN         NaN        None     NaN     NaN           NaN
# 10839         NaN         NaN        None     NaN     NaN           NaN
# 10840         NaN         NaN        None     NaN     NaN           NaN
# 10841         NaN         NaN        None     NaN     NaN           NaN
#
#        llzFreq  llzBearing llzIdent llzCategory
# 0          NaN         NaN     None        None
# 1          NaN         NaN     None        None
# 2          NaN         NaN     None        None
# 3          NaN         NaN     None        None
# 4          NaN         NaN     None        None
# ...        ...         ...      ...         ...
# 10837      NaN         NaN     None        None
# 10838      NaN         NaN     None        None
# 10839      NaN         NaN     None        None
# 10840      NaN         NaN     None        None
# 10841      NaN         NaN     None        None
#
# [10842 rows x 33 columns]

# %%
database

data_not_found = []

for row in database.itertuples():
    print("{} - {}".format(row.airportICAO, row.rwyIdent))
    
    #Ngambil data
    OAData.loc[(OAData["airport_ident"] == row.airportICAO)]
    
    #Ngambil identifier
    if (row.rwyIdent in OAData.loc[(OAData["airport_ident"] == row.airportICAO) & ((OAData["le_ident"] == row.rwyIdent) | (OAData["he_ident"] == row.rwyIdent)), "le_ident"].to_string().split(" ")):
        is_le = True
        identifier = "le_ident"
        
    elif (row.rwyIdent in OAData.loc[(OAData["airport_ident"] == row.airportICAO) & ((OAData["le_ident"] == row.rwyIdent) | (OAData["he_ident"] == row.rwyIdent)), "he_ident"].to_string().split(" ")):
        is_le = False
        identifier = "he_ident"
        
    else:
        identifier = "not_found"
        print("Data not found")
    
    print(identifier)
    print(row.airportICAO)
    print(row.rwyIdent)
    
    if identifier != "not_found":
        #Ekstrak data
        if is_le:
            cursor = "le_heading_degT"
        else:
            cursor = "he_heading_degT"
            (OAData["airport_ident"] == "AYPY") & (OAData["le_ident"] == "14L")
        print(OAData.loc[(OAData["airport_ident"] == row.airportICAO) & (OAData[identifier] == row.rwyIdent), cursor].to_string().split(" "))
        try:
            rtb = OAData.loc[(OAData["airport_ident"] == row.airportICAO) & (OAData[identifier] == row.rwyIdent), cursor].to_string().split(" ")[4]
        except:
            rtb = OAData.loc[(OAData["airport_ident"] == row.airportICAO) & (OAData[identifier] == row.rwyIdent), cursor].to_string().split(" ")[3]
        database.loc[(database["airportICAO"] == row.airportICAO) & (database["rwyIdent"] == row.rwyIdent), "rwyTrueBearing"] = rtb

        if is_le:
            cursor = "le_elevation_ft"
        else:
            cursor = "he_elevation_ft"
        print(OAData.loc[(OAData["airport_ident"] == row.airportICAO), cursor].to_string().split(" "))
        try:
            rte = OAData.loc[(OAData["airport_ident"] == row.airportICAO) & (OAData[identifier] == row.rwyIdent), cursor].to_string().split(" ")[4]
        except:
            rte = OAData.loc[(OAData["airport_ident"] == row.airportICAO) & (OAData[identifier] == row.rwyIdent), cursor].to_string().split(" ")[3]
        rte = float(rte)*0.3048
        database.loc[(database["airportICAO"] == row.airportICAO) & (database["rwyIdent"] == row.rwyIdent), "rwyThresElevation"] = rte

        cursor = "width_ft"
        #print(OAData.loc[(OAData["airport_ident"] == row.airportICAO), cursor].to_string().split(" "))
        try:
            wft = OAData.loc[(OAData["airport_ident"] == row.airportICAO) & (OAData[identifier] == row.rwyIdent), cursor].to_string().split(" ")[4]
        except:
            wft = OAData.loc[(OAData["airport_ident"] == row.airportICAO) & (OAData[identifier] == row.rwyIdent), cursor].to_string().split(" ")[3]
        wft = float(wft)*0.3048
        database.loc[(database["airportICAO"] == row.airportICAO) & (database["rwyIdent"] == row.rwyIdent), "rwyWidth"] = wft

        if is_le:
            cursor = "le_longitude_deg"
        else:
            cursor = "he_longitude_deg"
        #print(OAData.loc[(OAData["airport_ident"] == row.airportICAO), cursor].to_string().split(" "))
        try:
            lon = OAData.loc[(OAData["airport_ident"] == row.airportICAO) & (OAData[identifier] == row.rwyIdent), cursor].to_string().split(" ")[4]
        except:
            lon = OAData.loc[(OAData["airport_ident"] == row.airportICAO) & (OAData[identifier] == row.rwyIdent), cursor].to_string().split(" ")[3]
        database.loc[(database["airportICAO"] == row.airportICAO) & (database["rwyIdent"] == row.rwyIdent), "rwyLon"] = lon

        if is_le:
            cursor = "le_latitude_deg"
        else:
            cursor = "he_latitude_deg"
        #print(OAData.loc[(OAData["airport_ident"] == row.airportICAO), cursor].to_string().split(" "))
        try:
            lat = OAData.loc[(OAData["airport_ident"] == row.airportICAO) & (OAData[identifier] == row.rwyIdent), cursor].to_string().split(" ")[4]
        except:
            lat = OAData.loc[(OAData["airport_ident"] == row.airportICAO) & (OAData[identifier] == row.rwyIdent), cursor].to_string().split(" ")[3]
        database.loc[(database["airportICAO"] == row.airportICAO) & (database["rwyIdent"] == row.rwyIdent), "rwyLat"] = lat

        cursor = "length_ft"
        #print(OAData.loc[(OAData["airport_ident"] == row.airportICAO), cursor].to_string().split(" "))
        try:
            leng = OAData.loc[(OAData["airport_ident"] == row.airportICAO) & (OAData[identifier] == row.rwyIdent), cursor].to_string().split(" ")[4]
        except:
            leng = OAData.loc[(OAData["airport_ident"] == row.airportICAO) & (OAData[identifier] == row.rwyIdent), cursor].to_string().split(" ")[3]
        leng = float(leng)*0.3048 
        database.loc[(database["airportICAO"] == row.airportICAO) & (database["rwyIdent"] == row.rwyIdent), "rwyLength"] = leng

        cursor = "surface"
        #print(OAData.loc[(OAData["airport_ident"] == row.airportICAO), cursor].to_string().split(" "))
        try:
            sur = OAData.loc[(OAData["airport_ident"] == row.airportICAO) & (OAData[identifier] == row.rwyIdent), cursor].to_string().split(" ")[4]
        except:
            sur = OAData.loc[(OAData["airport_ident"] == row.airportICAO) & (OAData[identifier] == row.rwyIdent), cursor].to_string().split(" ")[3]
        database.loc[(database["airportICAO"] == row.airportICAO) & (database["rwyIdent"] == row.rwyIdent), "rwySurface"] = sur
    
    else:
        data_not_found.append("{}|{}".format(row.airportICAO, row.rwyIdent))
    
database
# Out:
# AGGH - 06
# le_ident
# AGGH
# 06
# ['10787', '', '', '', '68.0']
# ['10787', '', '', '', '28.0']
# AGGH - 24
# he_ident
# AGGH
# 24
# ['10787', '', '', '', '248.0']
# ['10787', '', '', '', '14.0']
# ANYN - 12
# le_ident
# ANYN
# 12
# ['11016', '', '', '', '121.0']
# ['11016', '', '', '', '22.0']
# ANYN - 30
# he_ident
# ANYN
# 30
# ['11016', '', '', '', '301.0']
# ['11016', '', '', '', '20.0']
# AYBK - 04
# le_ident
# AYBK
# 04
# ['11679', '', '', '', '48.0']
# ['11679', '', '', '', '11.0']
# AYBK - 22
# he_ident
# AYBK
# 22
# ['11679', '', '', '', '228.0']
# ['11679', '', '', '', '9.0']
# AYDU - 14
# le_ident
# AYDU
# 14
# ['11691', '', '', '', '135.0']
# ['11691', '', '', '', '13.0']
# AYDU - 32
# he_ident
# AYDU
# 32
# ['11691', '', '', '', '315.0']
# ['11691', '', '', '', '19.0']
# AYGN - 09
# le_ident
# AYGN
# 09
# ['11714', '', '', '', '101.3']
# ['11714', '', '', '', '65.0']
# AYGN - 27
# he_ident
# AYGN
# 27
# ['11714', '', '', '', '281.3']
# ['11714', '', '', '', '65.0']
# AYKI - 07
# le_ident
# AYKI
# 07
# ['11741', '', '', 'NaN']
# ['11741', '', '', '', '97.0']
# AYKI - 25
# he_ident
# AYKI
# 25
# ['11741', '', '', 'NaN']
# ['11741', '', '', '', '102.0']
# AYKV - 12
# le_ident
# AYKV
# 12
# ['11745', '', '', '', '124.9']
# ['11745', '', '', '', '13.0']
# AYKV - 30
# he_ident
# AYKV
# 30
# ['11745', '', '', '', '304.9']
# ['11745', '', '', '', '7.0']
# AYMD - 07
# le_ident
# AYMD
# 07
# ['11754', '', '', '', '75.0']
# ['11754', '', '', '', '20.0']
# AYMD - 25
# he_ident
# AYMD
# 25
# ['11754', '', '', '', '255.0']
# ['11754', '', '', '', '7.0']
# AYMO - 16
# le_ident
# AYMO
# 16
# ['11758', '', '', '', '161.0']
# ['11758', '', '', '', '4.0']
# AYMO - 34
# he_ident
# AYMO
# 34
# ['11758', '', '', '', '341.0']
# ['11758', '', '', '', '8.0']
# AYMR - 09
# le_ident
# AYMR
# 09
# ['11759', '', '', 'NaN']
# ['11759', '', '', '', '2741.0']
# AYMR - 27
# he_ident
# AYMR
# 27
# ['11759', '', '', 'NaN']
# ['11759', '', '', '', '2741.0']
# AYMS - 08
# le_ident
# AYMS
# 08
# ['11760', '', '', 'NaN']
# ['11760', '', '', '', '36.0']
# AYMS - 26
# he_ident
# AYMS
# 26
# ['11760', '', '', 'NaN']
# ['11760', '', '', '', '8.0']
# AYNZ - 09
# le_ident
# AYNZ
# 09
# ['11765', '', '', '', '95.0']
# ['11765', '', '', '', '239.0']
# AYNZ - 27
# he_ident
# AYNZ
# 27
# ['11765', '', '', '', '275.0']
# ['11765', '', '', '', '216.0']
# AYPY - 14L
# le_ident
# AYPY
# 14L
# ['11780', '', '', '', '148.4']
# ['11780', '', '', '', '103.0\n11781', '', '', '', '104.0']
# AYPY - 14R
# le_ident
# AYPY
# 14R
# ['11781', '', '', '', '142.0']
# ['11780', '', '', '', '103.0\n11781', '', '', '', '104.0']
# AYPY - 32L
# he_ident
# AYPY
# 32L
# ['11781', '', '', '', '322.0']
# ['11780', '', '', '', '128.0\n11781', '', '', '', '129.0']
# AYPY - 32R
# he_ident
# AYPY
# 32R
# ['11780', '', '', '', '328.4']
# ['11780', '', '', '', '128.0\n11781', '', '', '', '129.0']
# AYTK - 10
# le_ident
# AYTK
# 10
# ['11798', '', '', '', '106.0']
# ['11798', '', '', '', '15.0']
# AYTK - 28
# he_ident
# AYTK
# 28
# ['11798', '', '', '', '286.0']
# ['11798', '', '', '', '50.0']
# AYWK - 10
# le_ident
# AYWK
# 10
# ['11827', '', '', '', '103.9']
# ['11827', '', '', '', '16.0']
# AYWK - 28
# he_ident
# AYWK
# 28
# ['11827', '', '', '', '283.9']
# ['11827', '', '', '', '19.0']
# BGBW - 07
# le_ident
# BGBW
# 07
# ['11981', '', '', '', '41.0']
# ['11981', '', '', '', '11.0']
# BGBW - 25
# he_ident
# BGBW
# 25
# ['11981', '', '', '', '221.0']
# ['11981', '', '', '', '112.0']
# BGCO - 18
# le_ident
# BGCO
# 18
# ['11982', '', '', '', '157.0']
# ['11982', '', '', '', '45.0']
# BGCO - 36
# he_ident
# BGCO
# 36
# ['11982', '', '', '', '337.0']
# ['11982', '', '', '', '9.0']
# BGGH - 05
# le_ident
# BGGH
# 05
# ['11983', '', '', '', '19.0']
# ['11983', '', '', '', '271.0']
# BGGH - 23
# he_ident
# BGGH
# 23
# ['11983', '', '', '', '199.0']
# ['11983', '', '', '', '281.0']
# BGJN - 07
# Data not found
# not_found
# BGJN
# 07
# BGJN - 25
# Data not found
# not_found
# BGJN
# 25
# BGMQ - 16
# le_ident
# BGMQ
# 16
# ['11986', '', '', 'NaN']
# ['11986', '', '', '', '84.0']
# BGMQ - 34
# he_ident
# BGMQ
# 34
# ['11986', '', '', 'NaN']
# ['11986', '', '', '', '89.0']
# BGQQ - 18
# Data not found
# not_found
# BGQQ
# 18
# BGQQ - 36
# Data not found
# not_found
# BGQQ
# 36
# BGSF - 09
# le_ident
# BGSF
# 09
# ['11992', '', '', '', '61.6']
# ['11992', '', '', '', '100.0']
# BGSF - 27
# he_ident
# BGSF
# 27
# ['11992', '', '', '', '241.6']
# ['11992', '', '', '', '165.0']
# BGSS - 14
# Data not found
# not_found
# BGSS
# 14
# BGSS - 32
# Data not found
# not_found
# BGSS
# 32
# BGTL - 08
# le_ident
# BGTL
# 08
# ['11995', '', '', 'NaN']
# ['11995', '', '', '', '', '', 'NaN\n11996', '', '', '', '167.0']
# BGTL - 26
# he_ident
# BGTL
# 26
# ['11995', '', '', 'NaN']
# ['11995', '', '', '', '', '', 'NaN\n11996', '', '', '', '251.0']
# BGUK - 05
# le_ident
# BGUK
# 05
# ['11997', '', '', 'NaN']
# ['11997', '', '', '', '407.0']
# BGUK - 23
# he_ident
# BGUK
# 23
# ['11997', '', '', 'NaN']
# ['11997', '', '', '', '395.0']
# BGUQ - 16
# Data not found
# not_found
# BGUQ
# 16
# BGUQ - 34
# Data not found
# not_found
# BGUQ
# 34
# BIAR - 01
# le_ident
# BIAR
# 01
# ['12000', '', '', '', '355.0']
# ['12000', '', '', '', '7.0']
# BIAR - 19
# he_ident
# BIAR
# 19
# ['12000', '', '', '', '175.0']
# ['12000', '', '', '', '5.0']
# BIEG - 04
# Data not found
# not_found
# BIEG
# 04
# BIEG - 22
# Data not found
# not_found
# BIEG
# 22
# BIGR - 18
# Data not found
# not_found
# BIGR
# 18
# BIGR - 36
# Data not found
# not_found
# BIGR
# 36
# BIHN - 18
# le_ident
# BIHN
# 18
# ['12008', '', '', '', '168.0']
# ['12008', '', '', '', '24.0']
# BIHN - 36
# he_ident
# BIHN
# 36
# ['12008', '', '', '', '348.0']
# ['12008', '', '', '', '7.0']
# BIHU - 03
# Data not found
# not_found
# BIHU
# 03
# BIHU - 21
# Data not found
# not_found
# BIHU
# 21
# BIIS - 08
# le_ident
# BIIS
# 08
# ['12010', '', '', '', '62.0']
# ['12010', '', '', '', '8.0']
# BIIS - 26
# he_ident
# BIIS
# 26
# ['12010', '', '', '', '242.0']
# ['12010', '', '', '', '8.0']
# BIKF - 02
# Data not found
# not_found
# BIKF
# 02
# BIKF - 11
# Data not found
# not_found
# BIKF
# 11
# BIKF - 20
# Data not found
# not_found
# BIKF
# 20
# BIKF - 29
# Data not found
# not_found
# BIKF
# 29
# BIKR - 01
# le_ident
# BIKR
# 01
# ['12013', '', '', '', '351.0']
# ['12013', '', '', '', '8.0']
# BIKR - 19
# he_ident
# BIKR
# 19
# ['12013', '', '', '', '171.0']
# ['12013', '', '', '', '8.0']
# BIRK - 01
# le_ident
# BIRK
# 01
# ['12017', '', '', '', '355.0']
# ['12017', '', '', '', '23.0\n12018', '', '', '', '27.0\n12019', '', '', '', '17.0']
# BIRK - 06
# le_ident
# BIRK
# 06
# ['12018', '', '', '', '46.0']
# ['12017', '', '', '', '23.0\n12018', '', '', '', '27.0\n12019', '', '', '', '17.0']
# BIRK - 13
# le_ident
# BIRK
# 13
# ['12019', '', '', '', '117.0']
# ['12017', '', '', '', '23.0\n12018', '', '', '', '27.0\n12019', '', '', '', '17.0']
# BIRK - 19
# he_ident
# BIRK
# 19
# ['12017', '', '', '', '175.0']
# ['12017', '', '', '', '29.0\n12018', '', '', '', '39.0\n12019', '', '', '', '38.0']
# BIRK - 24
# he_ident
# BIRK
# 24
# ['12018', '', '', '', '226.0']
# ['12017', '', '', '', '29.0\n12018', '', '', '', '39.0\n12019', '', '', '', '38.0']
# BIRK - 31
# he_ident
# BIRK
# 31
# ['12019', '', '', '', '297.0']
# ['12017', '', '', '', '29.0\n12018', '', '', '', '39.0\n12019', '', '', '', '38.0']
# BITN - 02
# le_ident
# BITN
# 02
# ['12026', '', '', '', '2.7']
# ['12026', '', '', '', '51.0']
# BITN - 20
# he_ident
# BITN
# 20
# ['12026', '', '', '', '182.7']
# ['12026', '', '', '', '64.0']
# BIVM - 04
# Data not found
# not_found
# BIVM
# 04
# BIVM - 13
# Data not found
# not_found
# BIVM
# 13
# BIVM - 22
# Data not found
# not_found
# BIVM
# 22
# BIVM - 31
# Data not found
# not_found
# BIVM
# 31
# BIVO - 05
# le_ident
# BIVO
# 05
# ['12029', '', '', 'NaN']
# ['12029', '', '', '', '9.0']
# BIVO - 23
# he_ident
# BIVO
# 23
# ['12029', '', '', 'NaN']
# ['12029', '', '', '', '8.0']
# CAD4 - 16
# le_ident
# CAD4
# 16
# ['12631', '', '', '', '179.0']
# ['12631', '', '', 'NaN']
# CAD4 - 34
# he_ident
# CAD4
# 34
# ['12631', '', '', '', '359.0']
# ['12631', '', '', 'NaN']
# CAJ4 - 13
# le_ident
# CAJ4
# 13
# ['12641', '', '', '', '146.9']
# ['12640', '', '', '', '', '', '', 'NaN\n12641', '', '', '', '3615.0']
# CAJ4 - 31
# he_ident
# CAJ4
# 31
# ['12641', '', '', '', '326.9']
# ['12640', '', '', '', '', '', '', 'NaN\n12641', '', '', '', '3635.0']
# CBW4 - 15
# Data not found
# not_found
# CBW4
# 15
# CBW4 - 33
# Data not found
# not_found
# CBW4
# 33
# CCA6 - 14
# le_ident
# CCA6
# 14
# ['12714', '', '', 'NaN']
# ['12714', '', '', 'NaN']
# CCA6 - 32
# he_ident
# CCA6
# 32
# ['12714', '', '', 'NaN']
# ['12714', '', '', 'NaN']
# CCE4 - 15
# Data not found
# not_found
# CCE4
# 15
# CCE4 - 33
# Data not found
# not_found
# CCE4
# 33
# CCP4 - 12
# le_ident
# CCP4
# 12
# ['12744', '', '', 'NaN']
# ['12744', '', '', '', '335.0']
# CCP4 - 30
# he_ident
# CCP4
# 30
# ['12744', '', '', 'NaN']
# ['12744', '', '', '', '335.0']
# CCZ2 - 12
# le_ident
# CCZ2
# 12
# ['12761', '', '', 'NaN']
# ['12761', '', '', 'NaN']
# CCZ2 - 30
# he_ident
# CCZ2
# 30
# ['12761', '', '', 'NaN']
# ['12761', '', '', 'NaN']
# CEM3 - 09
# Data not found
# not_found
# CEM3
# 09
# CEM3 - 27
# Data not found
# not_found
# CEM3
# 27
# CJV7 - 17
# le_ident
# CJV7
# 17
# ['13177', '', '', 'NaN']
# ['13177', '', '', 'NaN']
# CJV7 - 35
# he_ident
# CJV7
# 35
# ['13177', '', '', 'NaN']
# ['13177', '', '', 'NaN']
# CKB6 - 12
# le_ident
# CKB6
# 12
# ['13208', '', '', 'NaN']
# ['13208', '', '', '', '696.0']
# CKB6 - 30
# he_ident
# CKB6
# 30
# ['13208', '', '', 'NaN']
# ['13208', '', '', '', '712.0']
# CKL3 - 16
# le_ident
# CKL3
# 16
# ['13250', '', '', 'NaN']
# ['13250', '', '', '', '814.0']
# CKL3 - 34
# he_ident
# CKL3
# 34
# ['13250', '', '', 'NaN']
# ['13250', '', '', '', '819.0']
# CKQ3 - 13
# le_ident
# CKQ3
# 13
# ['13262', '', '', 'NaN']
# ['13262', '', '', 'NaN']
# CKQ3 - 31
# he_ident
# CKQ3
# 31
# ['13262', '', '', 'NaN']
# ['13262', '', '', 'NaN']
# CNE3 - 07
# le_ident
# CNE3
# 07
# ['13534', '', '', 'NaN']
# ['13534', '', '', '', '800.0']
# CNE3 - 25
# he_ident
# CNE3
# 25
# ['13534', '', '', 'NaN']
# ['13534', '', '', '', '794.0']
# CNM5 - 12
# le_ident
# CNM5
# 12
# ['13556', '', '', 'NaN']
# ['13556', '', '', '', '866.0']
# CNM5 - 30
# he_ident
# CNM5
# 30
# ['13556', '', '', 'NaN']
# ['13556', '', '', '', '862.0']
# CNT3 - 09
# le_ident
# CNT3
# 09
# ['13580', '', '', 'NaN']
# ['13580', '', '', 'NaN']
# CNT3 - 27
# he_ident
# CNT3
# 27
# ['13580', '', '', 'NaN']
# ['13580', '', '', 'NaN']
# CPV7 - 13
# le_ident
# CPV7
# 13
# ['13788', '', '', 'NaN']
# ['13788', '', '', '', '1095.0']
# CPV7 - 31
# he_ident
# CPV7
# 31
# ['13788', '', '', 'NaN']
# ['13788', '', '', '', '1081.0']
# CSU2 - 14
# le_ident
# CSU2
# 14
# ['13864', '', '', 'NaN']
# ['13864', '', '', '', '43.0']
# CSU2 - 32
# he_ident
# CSU2
# 32
# ['13864', '', '', 'NaN']
# ['13864', '', '', '', '43.0']
# CYAC - 11
# le_ident
# CYAC
# 11
# ['14009', '', '', 'NaN']
# ['14009', '', '', '', '1339.0']
# CYAC - 29
# he_ident
# CYAC
# 29
# ['14009', '', '', 'NaN']
# ['14009', '', '', '', '1336.0']
# CYAG - 03
# le_ident
# CYAG
# 03
# ['14011', '', '', '', '34.8']
# ['14011', '', '', '', '1120.0\n14012', '', '', '', '1123.0']
# CYAG - 12
# le_ident
# CYAG
# 12
# ['14012', '', '', '', '126.0']
# ['14011', '', '', '', '1120.0\n14012', '', '', '', '1123.0']
# CYAG - 21
# he_ident
# CYAG
# 21
# ['14011', '', '', '', '214.8']
# ['14011', '', '', '', '1125.0\n14012', '', '', '', '1119.0']
# CYAG - 30
# he_ident
# CYAG
# 30
# ['14012', '', '', '', '306.0']
# ['14011', '', '', '', '1125.0\n14012', '', '', '', '1119.0']
# CYAM - 04
# le_ident
# CYAM
# 04
# ['14015', '', '', '', '33.5']
# ['14015', '', '', '', '612.0\n14016', '', '', '', '612.0']
# CYAM - 12
# le_ident
# CYAM
# 12
# ['14016', '', '', '', '107.8']
# ['14015', '', '', '', '612.0\n14016', '', '', '', '612.0']
# CYAM - 22
# he_ident
# CYAM
# 22
# ['14015', '', '', '', '213.5']
# ['14015', '', '', '', '630.0\n14016', '', '', '', '612.0']
# CYAM - 30
# he_ident
# CYAM
# 30
# ['14016', '', '', '', '287.8']
# ['14015', '', '', '', '630.0\n14016', '', '', '', '612.0']
# CYAQ - 03
# le_ident
# CYAQ
# 03
# ['14017', '', '', 'NaN']
# ['14017', '', '', '', '672.0']
# CYAQ - 21
# he_ident
# CYAQ
# 21
# ['14017', '', '', 'NaN']
# ['14017', '', '', '', '633.0']
# CYAS - 04
# Data not found
# not_found
# CYAS
# 04
# CYAS - 22
# Data not found
# not_found
# CYAS
# 22
# CYAT - 06
# le_ident
# CYAT
# 06
# ['14019', '', '', 'NaN']
# ['14019', '', '', 'NaN']
# CYAT - 24
# he_ident
# CYAT
# 24
# ['14019', '', '', 'NaN']
# ['14019', '', '', 'NaN']
# CYAY - 10
# le_ident
# CYAY
# 10
# ['14028', '', '', '', '80.0']
# ['14028', '', '', '', '108.0']
# CYAY - 28
# he_ident
# CYAY
# 28
# ['14028', '', '', '', '260.0']
# ['14028', '', '', '', '88.0']
# CYAZ - 07
# le_ident
# CYAZ
# 07
# ['14029', '', '', '', '90.0']
# ['14029', '', '', '', '75.0\n14030', '', '', '', '79.0\n14031', '', '', '', '80.0']
# CYAZ - 11
# le_ident
# CYAZ
# 11
# ['14030', '', '', '', '126.0']
# ['14029', '', '', '', '75.0\n14030', '', '', '', '79.0\n14031', '', '', '', '80.0']
# CYAZ - 16
# le_ident
# CYAZ
# 16
# ['14031', '', '', '', '175.0']
# ['14029', '', '', '', '75.0\n14030', '', '', '', '79.0\n14031', '', '', '', '80.0']
# CYAZ - 25
# he_ident
# CYAZ
# 25
# ['14029', '', '', '', '270.0']
# ['14029', '', '', '', '79.0\n14030', '', '', '', '76.0\n14031', '', '', '', '79.0']
# CYAZ - 29
# he_ident
# CYAZ
# 29
# ['14030', '', '', '', '306.0']
# ['14029', '', '', '', '79.0\n14030', '', '', '', '76.0\n14031', '', '', '', '79.0']
# CYAZ - 34
# he_ident
# CYAZ
# 34
# ['14031', '', '', '', '355.0']
# ['14029', '', '', '', '79.0\n14030', '', '', '', '76.0\n14031', '', '', '', '79.0']
# CYBB - 05
# le_ident
# CYBB
# 05
# ['14033', '', '', '', '49.0']
# ['14033', '', '', '', '56.0']
# CYBB - 23
# he_ident
# CYBB
# 23
# ['14033', '', '', '', '229.0']
# ['14033', '', '', '', '25.0']
# CYBC - 10
# le_ident
# CYBC
# 10
# ['14034', '', '', '', '80.5']
# ['14034', '', '', '', '70.0']
# CYBC - 28
# he_ident
# CYBC
# 28
# ['14034', '', '', '', '260.5']
# ['14034', '', '', '', '66.0']
# CYBF - 07
# le_ident
# CYBF
# 07
# ['14038', '', '', '', '90.0']
# ['14038', '', '', 'NaN']
# CYBF - 25
# he_ident
# CYBF
# 25
# ['14038', '', '', '', '270.0']
# ['14038', '', '', 'NaN']
# CYBG - 11
# le_ident
# CYBG
# 11
# ['14039', '', '', '', '90.6']
# ['14039', '', '', '', '519.0\n14040', '', '', '', '520.0']
# CYBG - 18
# le_ident
# CYBG
# 18
# ['14040', '', '', '', '163.4']
# ['14039', '', '', '', '519.0\n14040', '', '', '', '520.0']
# CYBG - 29
# he_ident
# CYBG
# 29
# ['14039', '', '', '', '270.6']
# ['14039', '', '', '', '511.0\n14040', '', '', '', '522.0']
# CYBG - 36
# he_ident
# CYBG
# 36
# ['14040', '', '', '', '343.4']
# ['14039', '', '', '', '511.0\n14040', '', '', '', '522.0']
# CYBK - 16
# Data not found
# not_found
# CYBK
# 16
# CYBK - 34
# Data not found
# not_found
# CYBK
# 34
# CYBL - 11
# Data not found
# not_found
# CYBL
# 11
# CYBL - 29
# Data not found
# not_found
# CYBL
# 29
# CYBQ - 07
# le_ident
# CYBQ
# 07
# ['14046', '', '', 'NaN']
# ['14045', '', '', '', '', '', 'NaN\n14046', '', '', '', '923.0']
# CYBQ - 25
# he_ident
# CYBQ
# 25
# ['14046', '', '', 'NaN']
# ['14045', '', '', '', '', '', 'NaN\n14046', '', '', '', '872.0']
# CYBR - 08
# le_ident
# CYBR
# 08
# ['14048', '', '', '', '90.0']
# ['14047', '', '', '', '', '', '', 'NaN\n14048', '', '', '', '1343.0\n14049', '', '', '', '1337.0']
# CYBR - 14
# le_ident
# CYBR
# 14
# ['14049', '', '', '', '150.0']
# ['14047', '', '', '', '', '', '', 'NaN\n14048', '', '', '', '1343.0\n14049', '', '', '', '1337.0']
# CYBR - 26
# he_ident
# CYBR
# 26
# ['14048', '', '', '', '270.0']
# ['14047', '', '', '', '', '', '', 'NaN\n14048', '', '', '', '1332.0\n14049', '', '', '', '1331.0']
# CYBR - 32
# he_ident
# CYBR
# 32
# ['14049', '', '', '', '330.0']
# ['14047', '', '', '', '', '', '', 'NaN\n14048', '', '', '', '1332.0\n14049', '', '', '', '1331.0']
# CYBT - 03
# le_ident
# CYBT
# 03
# ['14050', '', '', 'NaN']
# ['14050', '', '', '', '1136.0']
# CYBT - 21
# he_ident
# CYBT
# 21
# ['14050', '', '', 'NaN']
# ['14050', '', '', '', '1136.0']
# CYBV - 08
# le_ident
# CYBV
# 08
# ['14053', '', '', 'NaN']
# ['14053', '', '', '', '728.0']
# CYBV - 26
# he_ident
# CYBV
# 26
# ['14053', '', '', 'NaN']
# ['14053', '', '', '', '728.0']
# CYBX - 05
# le_ident
# CYBX
# 05
# ['14056', '', '', '', '27.5']
# ['14056', '', '', '', '79.0']
# CYBX - 23
# he_ident
# CYBX
# 23
# ['14056', '', '', '', '207.5']
# ['14056', '', '', '', '121.0']
# CYCA - 08
# Data not found
# not_found
# CYCA
# 08
# CYCA - 26
# Data not found
# not_found
# CYCA
# 26
# CYCB - 13
# Data not found
# not_found
# CYCB
# 13
# CYCB - 31
# Data not found
# not_found
# CYCB
# 31
# CYCC - 10
# le_ident
# CYCC
# 10
# ['14059', '', '', '', '83.3']
# ['14059', '', '', '', '171.0']
# CYCC - 28
# he_ident
# CYCC
# 28
# ['14059', '', '', '', '263.3']
# ['14059', '', '', '', '168.0']
# CYCD - 16
# le_ident
# CYCD
# 16
# ['14060', '', '', '', '181.0']
# ['14060', '', '', '', '75.0']
# CYCD - 34
# he_ident
# CYCD
# 34
# ['14060', '', '', '', '1.0']
# ['14060', '', '', '', '92.0']
# CYCG - 15
# le_ident
# CYCG
# 15
# ['14063', '', '', '', '169.0']
# ['14063', '', '', '', '1615.0']
# CYCG - 33
# he_ident
# CYCG
# 33
# ['14063', '', '', '', '349.0']
# ['14063', '', '', '', '1621.0']
# CYCH - 09
# le_ident
# CYCH
# 09
# ['14065', '', '', '', '72.0']
# ['14064', '', '', '', '', '69.0\n14065', '', '', '', '108.0\n14066', '', '', '', '106.0\n14067', '', '', '', '107.0']
# CYCH - 27
# he_ident
# CYCH
# 27
# ['14065', '', '', '', '252.0']
# ['14064', '', '', '', '90.0\n14065', '', '', '', '85.0\n14066', '', '', '', '85.0\n14067', '', '', '', '68.0']
# CYCL - 12
# le_ident
# CYCL
# 12
# ['14069', '', '', '', '105.0']
# ['14069', '', '', '', '132.0']
# CYCL - 30
# he_ident
# CYCL
# 30
# ['14069', '', '', '', '285.0']
# ['14069', '', '', '', '114.0']
# CYCN - 13
# le_ident
# CYCN
# 13
# ['14070', '', '', '', '119.2']
# ['14070', '', '', '', '840.0']
# CYCN - 31
# he_ident
# CYCN
# 31
# ['14070', '', '', '', '299.2']
# ['14070', '', '', '', '861.0']
# CYCO - 12
# Data not found
# not_found
# CYCO
# 12
# CYCO - 30
# Data not found
# not_found
# CYCO
# 30
# CYCR - 05
# le_ident
# CYCR
# 05
# ['14074', '', '', 'NaN']
# ['14074', '', '', 'NaN']
# CYCR - 23
# he_ident
# CYCR
# 23
# ['14074', '', '', 'NaN']
# ['14074', '', '', 'NaN']
# CYCS - 12
# Data not found
# not_found
# CYCS
# 12
# CYCS - 30
# Data not found
# not_found
# CYCS
# 30
# CYCW - 07
# le_ident
# CYCW
# 07
# ['14077', '', '', '', '81.3']
# ['14077', '', '', '', '31.0']
# CYCW - 25
# he_ident
# CYCW
# 25
# ['14077', '', '', '', '261.3']
# ['14077', '', '', '', '28.0']
# CYCY - 02
# Data not found
# not_found
# CYCY
# 02
# CYCY - 20
# Data not found
# not_found
# CYCY
# 20
# CYCZ - 15
# le_ident
# CYCZ
# 15
# ['14079', '', '', '', '170.0']
# ['14079', '', '', '', '2637.0']
# CYCZ - 33
# he_ident
# CYCZ
# 33
# ['14079', '', '', '', '350.0']
# ['14079', '', '', '', '2658.0']
# CYDA - 02
# Data not found
# not_found
# CYDA
# 02
# CYDA - 20
# Data not found
# not_found
# CYDA
# 20
# CYDB - 10
# le_ident
# CYDB
# 10
# ['14083', '', '', '', '128.0']
# ['14083', '', '', '', '2647.0']
# CYDB - 28
# he_ident
# CYDB
# 28
# ['14083', '', '', '', '308.0']
# ['14083', '', '', '', '2604.0']
# CYDF - 07
# le_ident
# CYDF
# 07
# ['14085', '', '', '', '47.8']
# ['14085', '', '', '', '50.0']
# CYDF - 25
# he_ident
# CYDF
# 25
# ['14085', '', '', '', '227.8']
# ['14085', '', '', '', '72.0']
# CYDL - 02
# le_ident
# CYDL
# 02
# ['14086', '', '', '', '48.0']
# ['14086', '', '', '', '2600.0']
# CYDL - 20
# he_ident
# CYDL
# 20
# ['14086', '', '', '', '228.0']
# ['14086', '', '', '', '2600.0']
# CYDN - 02
# le_ident
# CYDN
# 02
# ['14088', '', '', '', '29.0']
# ['14088', '', '', '', '989.0\n14089', '', '', '', '988.0\n14090', '', '', '', '989.0']
# CYDN - 08
# le_ident
# CYDN
# 08
# ['14089', '', '', '', '90.0']
# ['14088', '', '', '', '989.0\n14089', '', '', '', '988.0\n14090', '', '', '', '989.0']
# CYDN - 14
# le_ident
# CYDN
# 14
# ['14090', '', '', '', '150.0']
# ['14088', '', '', '', '989.0\n14089', '', '', '', '988.0\n14090', '', '', '', '989.0']
# CYDN - 20
# he_ident
# CYDN
# 20
# ['14088', '', '', '', '209.0']
# ['14088', '', '', '', '982.0\n14089', '', '', '', '982.0\n14090', '', '', '', '998.0']
# CYDN - 26
# he_ident
# CYDN
# 26
# ['14089', '', '', '', '270.0']
# ['14088', '', '', '', '982.0\n14089', '', '', '', '982.0\n14090', '', '', '', '998.0']
# CYDN - 32
# he_ident
# CYDN
# 32
# ['14090', '', '', '', '330.0']
# ['14088', '', '', '', '982.0\n14089', '', '', '', '982.0\n14090', '', '', '', '998.0']
# CYDP - 05
# Data not found
# not_found
# CYDP
# 05
# CYDP - 23
# Data not found
# not_found
# CYDP
# 23
# CYDQ - 06
# le_ident
# CYDQ
# 06
# ['14093', '', '', '', '85.0']
# ['14093', '', '', '', '2146.0']
# CYDQ - 24
# he_ident
# CYDQ
# 24
# ['14093', '', '', '', '265.0']
# ['14093', '', '', '', '2145.0']
# CYEG - 02
# le_ident
# CYEG
# 02
# ['14096', '', '', '', '33.9']
# ['14096', '', '', '', '2322.0\n14097', '', '', '', '2325.0']
# CYEG - 12
# le_ident
# CYEG
# 12
# ['14097', '', '', '', '135.1']
# ['14096', '', '', '', '2322.0\n14097', '', '', '', '2325.0']
# CYEG - 20
# he_ident
# CYEG
# 20
# ['14096', '', '', '', '213.9']
# ['14096', '', '', '', '2337.0\n14097', '', '', '', '2372.0']
# CYEG - 30
# he_ident
# CYEG
# 30
# ['14097', '', '', '', '315.1']
# ['14096', '', '', '', '2337.0\n14097', '', '', '', '2372.0']
# CYEK - 15
# Data not found
# not_found
# CYEK
# 15
# CYEK - 33
# Data not found
# not_found
# CYEK
# 33
# CYEM - 02
# le_ident
# CYEM
# 02
# ['14100', '', '', '', '11.6']
# ['14100', '', '', '', '851.0']
# CYEM - 20
# he_ident
# CYEM
# 20
# ['14100', '', '', '', '191.6']
# ['14100', '', '', '', '869.0']
# CYEN - 08
# le_ident
# CYEN
# 08
# ['14101', '', '', '', '90.0']
# ['14101', '', '', '', '1904.0\n14102', '', '', '', '', '', '', 'NaN']
# CYEN - 15
# le_ident
# CYEN
# 15
# ['14102', '', '', '', '158.0']
# ['14101', '', '', '', '1904.0\n14102', '', '', '', '', '', '', 'NaN']
# CYEN - 26
# he_ident
# CYEN
# 26
# ['14101', '', '', '', '270.0']
# ['14101', '', '', '', '1902.0\n14102', '', '', '', '', '', '', 'NaN']
# CYEN - 33
# he_ident
# CYEN
# 33
# ['14102', '', '', '', '338.0']
# ['14101', '', '', '', '1902.0\n14102', '', '', '', '', '', '', 'NaN']
# CYER - 15
# le_ident
# CYER
# 15
# ['14103', '', '', 'NaN']
# ['14103', '', '', 'NaN']
# CYER - 33
# he_ident
# CYER
# 33
# ['14103', '', '', 'NaN']
# ['14103', '', '', 'NaN']
# CYET - 07
# le_ident
# CYET
# 07
# ['14105', '', '', '', '91.0']
# ['14105', '', '', '', '3041.0']
# CYET - 25
# he_ident
# CYET
# 25
# ['14105', '', '', '', '271.0']
# ['14105', '', '', '', '3020.0']
# CYEU - 10
# Data not found
# not_found
# CYEU
# 10
# CYEU - 28
# Data not found
# not_found
# CYEU
# 28
# CYEV - 06
# le_ident
# CYEV
# 06
# ['14107', '', '', '', '85.8']
# ['14107', '', '', '', '197.0']
# CYEV - 24
# he_ident
# CYEV
# 24
# ['14107', '', '', '', '265.8']
# ['14107', '', '', '', '224.0']
# CYFA - 10
# le_ident
# CYFA
# 10
# ['14109', '', '', 'NaN']
# ['14109', '', '', 'NaN']
# CYFA - 28
# he_ident
# CYFA
# 28
# ['14109', '', '', 'NaN']
# ['14109', '', '', 'NaN']
# CYFB - 17
# Data not found
# not_found
# CYFB
# 17
# CYFB - 35
# Data not found
# not_found
# CYFB
# 35
# CYFC - 09
# le_ident
# CYFC
# 09
# ['14111', '', '', '', '70.7']
# ['14111', '', '', '', '64.0\n14112', '', '', '', '53.0']
# CYFC - 15
# le_ident
# CYFC
# 15
# ['14112', '', '', '', '131.1']
# ['14111', '', '', '', '64.0\n14112', '', '', '', '53.0']
# CYFC - 27
# he_ident
# CYFC
# 27
# ['14111', '', '', '', '250.7']
# ['14111', '', '', '', '57.0\n14112', '', '', '', '57.0']
# CYFC - 33
# he_ident
# CYFC
# 33
# ['14112', '', '', '', '311.1']
# ['14111', '', '', '', '57.0\n14112', '', '', '', '57.0']
# CYFH - 09
# le_ident
# CYFH
# 09
# ['14117', '', '', 'NaN']
# ['14117', '', '', 'NaN']
# CYFH - 27
# he_ident
# CYFH
# 27
# ['14117', '', '', 'NaN']
# ['14117', '', '', 'NaN']
# CYFJ - 03
# le_ident
# CYFJ
# 03
# ['14118', '', '', '', '11.0']
# ['14118', '', '', '', '814.0']
# CYFJ - 21
# he_ident
# CYFJ
# 21
# ['14118', '', '', '', '191.0']
# ['14118', '', '', '', '827.0']
# CYFO - 18
# le_ident
# CYFO
# 18
# ['14119', '', '', '', '189.0']
# ['14119', '', '', '', '997.0']
# CYFO - 36
# he_ident
# CYFO
# 36
# ['14119', '', '', '', '9.0']
# ['14119', '', '', '', '972.0']
# CYFR - 12
# le_ident
# CYFR
# 12
# ['14120', '', '', '', '139.0']
# ['14120', '', '', '', '524.0']
# CYFR - 30
# he_ident
# CYFR
# 30
# ['14120', '', '', '', '319.0']
# ['14120', '', '', '', '525.0']
# CYFS - 13
# Data not found
# not_found
# CYFS
# 13
# CYFS - 31
# Data not found
# not_found
# CYFS
# 31
# CYGH - 06
# le_ident
# CYGH
# 06
# ['14128', '', '', '', '90.0']
# ['14128', '', '', '', '251.0']
# CYGH - 24
# he_ident
# CYGH
# 24
# ['14128', '', '', '', '270.0']
# ['14128', '', '', '', '265.0']
# CYGK - 01
# le_ident
# CYGK
# 01
# ['14129', '', '', '', '355.8']
# ['14129', '', '', '', '301.0\n14130', '', '', '', '301.0']
# CYGK - 07
# le_ident
# CYGK
# 07
# ['14130', '', '', '', '54.0']
# ['14129', '', '', '', '301.0\n14130', '', '', '', '301.0']
# CYGK - 19
# he_ident
# CYGK
# 19
# ['14129', '', '', '', '175.8']
# ['14129', '', '', '', '302.0\n14130', '', '', '', '297.0']
# CYGK - 25
# he_ident
# CYGK
# 25
# ['14130', '', '', '', '234.0']
# ['14129', '', '', '', '302.0\n14130', '', '', '', '297.0']
# CYGL - 13
# le_ident
# CYGL
# 13
# ['14131', '', '', '', '113.0']
# ['14131', '', '', '', '595.0']
# CYGL - 31
# he_ident
# CYGL
# 31
# ['14131', '', '', '', '293.0']
# ['14131', '', '', '', '639.0']
# CYGM - 15
# le_ident
# CYGM
# 15
# ['14132', '', '', '', '150.3']
# ['14132', '', '', '', '753.0']
# CYGM - 33
# he_ident
# CYGM
# 33
# ['14132', '', '', '', '330.3']
# ['14132', '', '', '', '743.0']
# CYGO - 14
# le_ident
# CYGO
# 14
# ['14133', '', '', 'NaN']
# ['14133', '', '', '', '601.0']
# CYGO - 32
# he_ident
# CYGO
# 32
# ['14133', '', '', 'NaN']
# ['14133', '', '', '', '616.0']
# CYGP - 11
# Data not found
# not_found
# CYGP
# 11
# CYGP - 29
# Data not found
# not_found
# CYGP
# 29
# CYGQ - 08
# le_ident
# CYGQ
# 08
# ['14135', '', '', '', '72.0']
# ['14135', '', '', '', '1140.0']
# CYGQ - 26
# he_ident
# CYGQ
# 26
# ['14135', '', '', '', '252.0']
# ['14135', '', '', '', '1139.0']
# CYGR - 07
# le_ident
# CYGR
# 07
# ['14136', '', '', '', '53.0']
# ['14136', '', '', '', '22.0\n14137', '', '', '', '', '9.0']
# CYGR - 16
# le_ident
# CYGR
# 16
# ['14137', '', '', '', '138.7']
# ['14136', '', '', '', '22.0\n14137', '', '', '', '', '9.0']
# CYGR - 25
# he_ident
# CYGR
# 25
# ['14136', '', '', '', '233.0']
# ['14136', '', '', '', '12.0\n14137', '', '', '', '35.0']
# CYGR - 34
# he_ident
# CYGR
# 34
# ['14137', '', '', '', '318.7']
# ['14136', '', '', '', '12.0\n14137', '', '', '', '35.0']
# CYGT - 15
# Data not found
# not_found
# CYGT
# 15
# CYGT - 33
# Data not found
# not_found
# CYGT
# 33
# CYGV - 09
# Data not found
# not_found
# CYGV
# 09
# CYGV - 27
# Data not found
# not_found
# CYGV
# 27
# CYGW - 04
# le_ident
# CYGW
# 04
# ['14140', '', '', 'NaN']
# ['14140', '', '', '', '32.0']
# CYGW - 22
# he_ident
# CYGW
# 22
# ['14140', '', '', 'NaN']
# ['14140', '', '', '', '26.0']
# CYGX - 05
# le_ident
# CYGX
# 05
# ['14141', '', '', 'NaN']
# ['14141', '', '', '', '476.0']
# CYGX - 23
# he_ident
# CYGX
# 23
# ['14141', '', '', 'NaN']
# ['14141', '', '', '', '474.0']
# CYGZ - 14
# Data not found
# not_found
# CYGZ
# 14
# CYGZ - 32
# Data not found
# not_found
# CYGZ
# 32
# CYHA - 01
# Data not found
# not_found
# CYHA
# 01
# CYHA - 19
# Data not found
# not_found
# CYHA
# 19
# CYHB - 05
# le_ident
# CYHB
# 05
# ['14143', '', '', '', '66.0']
# ['14143', '', '', '', '1106.0\n14144', '', '', '', '', '', '', 'NaN']
# CYHB - 10
# le_ident
# CYHB
# 10
# ['14144', '', '', '', '110.0']
# ['14143', '', '', '', '1106.0\n14144', '', '', '', '', '', '', 'NaN']
# CYHB - 23
# he_ident
# CYHB
# 23
# ['14143', '', '', '', '246.0']
# ['14143', '', '', '', '1159.0\n14144', '', '', '', '', '', '', 'NaN']
# CYHB - 28
# he_ident
# CYHB
# 28
# ['14144', '', '', '', '290.0']
# ['14143', '', '', '', '1159.0\n14144', '', '', '', '', '', '', 'NaN']
# CYHD - 12
# le_ident
# CYHD
# 12
# ['14146', '', '', '', '114.0']
# ['14145', '', '', '', '1351.0\n14146', '', '', '', '1354.0']
# CYHD - 30
# he_ident
# CYHD
# 30
# ['14146', '', '', '', '294.0']
# ['14145', '', '', '', '1351.0\n14146', '', '', '', '1352.0']
# CYHF - 04
# le_ident
# CYHF
# 04
# ['14148', '', '', '', '32.9']
# ['14148', '', '', '', '825.0']
# CYHF - 22
# he_ident
# CYHF
# 22
# ['14148', '', '', '', '212.9']
# ['14148', '', '', '', '819.0']
# CYHH - 09
# le_ident
# CYHH
# 09
# ['14149', '', '', 'NaN']
# ['14149', '', '', '', '802.0']
# CYHH - 27
# he_ident
# CYHH
# 27
# ['14149', '', '', 'NaN']
# ['14149', '', '', '', '784.0']
# CYHI - 06
# Data not found
# not_found
# CYHI
# 06
# CYHI - 24
# Data not found
# not_found
# CYHI
# 24
# CYHK - 13
# Data not found
# not_found
# CYHK
# 13
# CYHK - 31
# Data not found
# not_found
# CYHK
# 31
# CYHM - 06
# le_ident
# CYHM
# 06
# ['14152', '', '', '', '49.0']
# ['14152', '', '', '', '771.0\n14153', '', '', '', '772.0']
# CYHM - 12
# le_ident
# CYHM
# 12
# ['14153', '', '', '', '107.0']
# ['14152', '', '', '', '771.0\n14153', '', '', '', '772.0']
# CYHM - 24
# he_ident
# CYHM
# 24
# ['14152', '', '', '', '229.0']
# ['14152', '', '', '', '755.0\n14153', '', '', '', '765.0']
# CYHM - 30
# he_ident
# CYHM
# 30
# ['14153', '', '', '', '287.0']
# ['14152', '', '', '', '755.0\n14153', '', '', '', '765.0']
# CYHN - 07
# le_ident
# CYHN
# 07
# ['14154', '', '', '', '59.1']
# ['14154', '', '', '', '1099.0']
# CYHN - 25
# he_ident
# CYHN
# 25
# ['14154', '', '', '', '239.1']
# ['14154', '', '', '', '1087.0']
# CYHO - 07
# le_ident
# CYHO
# 07
# ['14155', '', '', 'NaN']
# ['14155', '', '', 'NaN']
# CYHO - 25
# he_ident
# CYHO
# 25
# ['14155', '', '', 'NaN']
# ['14155', '', '', 'NaN']
# CYHR - 08
# le_ident
# CYHR
# 08
# ['14156', '', '', '', '55.0']
# ['14156', '', '', '', '31.0']
# CYHR - 26
# he_ident
# CYHR
# 26
# ['14156', '', '', '', '235.0']
# ['14156', '', '', '', '39.0']
# CYHU - 06L
# le_ident
# CYHU
# 06L
# ['14160', '', '', '', '47.0']
# ['14160', '', '', '', '86.0\n14161', '', '', '', '84.0\n14162', '', '', '', '87.0']
# CYHU - 06R
# le_ident
# CYHU
# 06R
# ['14161', '', '', '', '47.1']
# ['14160', '', '', '', '86.0\n14161', '', '', '', '84.0\n14162', '', '', '', '87.0']
# CYHU - 10
# le_ident
# CYHU
# 10
# ['14162', '', '', '', '83.7']
# ['14160', '', '', '', '86.0\n14161', '', '', '', '84.0\n14162', '', '', '', '87.0']
# CYHU - 24L
# he_ident
# CYHU
# 24L
# ['14161', '', '', '', '227.2']
# ['14160', '', '', '', '87.0\n14161', '', '', '', '88.0\n14162', '', '', '', '84.0']
# CYHU - 24R
# he_ident
# CYHU
# 24R
# ['14160', '', '', '', '227.0']
# ['14160', '', '', '', '87.0\n14161', '', '', '', '88.0\n14162', '', '', '', '84.0']
# CYHU - 28
# he_ident
# CYHU
# 28
# ['14162', '', '', '', '263.8']
# ['14160', '', '', '', '87.0\n14161', '', '', '', '88.0\n14162', '', '', '', '84.0']
# CYHY - 13
# Data not found
# not_found
# CYHY
# 13
# CYHY - 31
# Data not found
# not_found
# CYHY
# 31
# CYHZ - 05
# le_ident
# CYHZ
# 05
# ['14165', '', '', '', '35.0']
# ['14165', '', '', '', '449.0\n14166', '', '', '', '435.0']
# CYHZ - 14
# le_ident
# CYHZ
# 14
# ['14166', '', '', '', '126.0']
# ['14165', '', '', '', '449.0\n14166', '', '', '', '435.0']
# CYHZ - 23
# he_ident
# CYHZ
# 23
# ['14165', '', '', '', '215.0']
# ['14165', '', '', '', '443.0\n14166', '', '', '', '476.0']
# CYHZ - 32
# he_ident
# CYHZ
# 32
# ['14166', '', '', '', '306.0']
# ['14165', '', '', '', '443.0\n14166', '', '', '', '476.0']
# CYIB - 04
# le_ident
# CYIB
# 04
# ['14167', '', '', '', '39.1']
# ['14167', '', '', '', '1385.0']
# CYIB - 22
# he_ident
# CYIB
# 22
# ['14167', '', '', '', '219.1']
# ['14167', '', '', '', '1408.0']
# CYIF - 02
# le_ident
# CYIF
# 02
# ['14169', '', '', '', '352.9']
# ['14169', '', '', '', '19.0']
# CYIF - 20
# he_ident
# CYIF
# 20
# ['14169', '', '', '', '172.9']
# ['14169', '', '', '', '13.0']
# CYIK - 08
# Data not found
# not_found
# CYIK
# 08
# CYIK - 26
# Data not found
# not_found
# CYIK
# 26
# CYIO - 02
# Data not found
# not_found
# CYIO
# 02
# CYIO - 20
# Data not found
# not_found
# CYIO
# 20
# CYIV - 12
# le_ident
# CYIV
# 12
# ['14172', '', '', '', '123.0']
# ['14172', '', '', '', '770.0']
# CYIV - 30
# he_ident
# CYIV
# 30
# ['14172', '', '', '', '303.0']
# ['14172', '', '', '', '770.0']
# CYJN - 02
# le_ident
# CYJN
# 02
# ['14176', '', '', '', '360.0']
# ['14176', '', '', '', '129.0\n14177', '', '', '', '133.0\n14178', '', '', '', '136.0']
# CYJN - 06
# le_ident
# CYJN
# 06
# ['14177', '', '', '', '45.1']
# ['14176', '', '', '', '129.0\n14177', '', '', '', '133.0\n14178', '', '', '', '136.0']
# CYJN - 11
# le_ident
# CYJN
# 11
# ['14178', '', '', '', '90.0']
# ['14176', '', '', '', '129.0\n14177', '', '', '', '133.0\n14178', '', '', '', '136.0']
# CYJN - 20
# he_ident
# CYJN
# 20
# ['14176', '', '', '', '180.0']
# ['14176', '', '', '', '126.0\n14177', '', '', '', '127.0\n14178', '', '', '', '128.0']
# CYJN - 24
# he_ident
# CYJN
# 24
# ['14177', '', '', '', '225.1']
# ['14176', '', '', '', '126.0\n14177', '', '', '', '127.0\n14178', '', '', '', '128.0']
# CYJN - 29
# he_ident
# CYJN
# 29
# ['14178', '', '', '', '270.0']
# ['14176', '', '', '', '126.0\n14177', '', '', '', '127.0\n14178', '', '', '', '128.0']
# CYJT - 02
# le_ident
# CYJT
# 02
# ['14180', '', '', '', '355.5']
# ['14180', '', '', '', '19.0\n14181', '', '', '', '15.0']
# CYJT - 09
# le_ident
# CYJT
# 09
# ['14181', '', '', '', '71.7']
# ['14180', '', '', '', '19.0\n14181', '', '', '', '15.0']
# CYJT - 20
# he_ident
# CYJT
# 20
# ['14180', '', '', '', '175.5']
# ['14180', '', '', '', '36.0\n14181', '', '', '', '84.0']
# CYJT - 27
# he_ident
# CYJT
# 27
# ['14181', '', '', '', '251.7']
# ['14180', '', '', '', '36.0\n14181', '', '', '', '84.0']
# CYKA - 04
# le_ident
# CYKA
# 04
# ['14182', '', '', '', '61.0']
# ['14182', '', '', '', '1129.0\n14183', '', '', '', '1130.0']
# CYKA - 08
# Data not found
# not_found
# CYKA
# 08
# CYKA - 22
# he_ident
# CYKA
# 22
# ['14182', '', '', '', '241.0']
# ['14182', '', '', '', '1129.0\n14183', '', '', '', '1133.0']
# CYKA - 26
# Data not found
# not_found
# CYKA
# 26
# CYKD - 13
# le_ident
# CYKD
# 13
# ['14186', '', '', '', '153.0']
# ['14185', '', '', '', '', 'NaN\n14186', '', '', '', '19.0']
# CYKD - 31
# he_ident
# CYKD
# 31
# ['14186', '', '', '', '333.0']
# ['14185', '', '', '', '', 'NaN\n14186', '', '', '', '20.0']
# CYKF - 08
# le_ident
# CYKF
# 08
# ['14187', '', '', '', '64.1']
# ['14187', '', '', '', '1024.0\n14188', '', '', '', '1027.0']
# CYKF - 14
# le_ident
# CYKF
# 14
# ['14188', '', '', '', '129.0']
# ['14187', '', '', '', '1024.0\n14188', '', '', '', '1027.0']
# CYKF - 26
# he_ident
# CYKF
# 26
# ['14187', '', '', '', '244.1']
# ['14187', '', '', '', '1054.0\n14188', '', '', '', '1025.0']
# CYKF - 32
# he_ident
# CYKF
# 32
# ['14188', '', '', '', '309.0']
# ['14187', '', '', '', '1054.0\n14188', '', '', '', '1025.0']
# CYKG - 15
# le_ident
# CYKG
# 15
# ['14189', '', '', 'NaN']
# ['14189', '', '', '', '501.0']
# CYKG - 33
# he_ident
# CYKG
# 33
# ['14189', '', '', 'NaN']
# ['14189', '', '', '', '463.0']
# CYKL - 18
# Data not found
# not_found
# CYKL
# 18
# CYKL - 36
# Data not found
# not_found
# CYKL
# 36
# CYKO - 08
# le_ident
# CYKO
# 08
# ['14194', '', '', '', '62.9']
# ['14194', '', '', '', '41.0']
# CYKO - 26
# he_ident
# CYKO
# 26
# ['14194', '', '', '', '242.9']
# ['14194', '', '', '', '75.0']
# CYKQ - 06
# le_ident
# CYKQ
# 06
# ['14195', '', '', 'NaN']
# ['14195', '', '', '', '78.0']
# CYKQ - 24
# he_ident
# CYKQ
# 24
# ['14195', '', '', 'NaN']
# ['14195', '', '', '', '77.0']
# CYKX - 08
# le_ident
# CYKX
# 08
# ['14196', '', '', '', '71.0']
# ['14196', '', '', '', '1157.0']
# CYKX - 26
# he_ident
# CYKX
# 26
# ['14196', '', '', '', '251.0']
# ['14196', '', '', '', '1136.0']
# CYKY - 08
# Data not found
# not_found
# CYKY
# 08
# CYKY - 17
# le_ident
# CYKY
# 17
# ['14198', '', '', '', '179.9']
# ['14197', '', '', '', '2277.0\n14198', '', '', '', '', '', '', 'NaN']
# CYKY - 26
# Data not found
# not_found
# CYKY
# 26
# CYKY - 35
# he_ident
# CYKY
# 35
# ['14198', '', '', '', '359.9']
# ['14197', '', '', '', '2277.0\n14198', '', '', '', '', '', '', 'NaN']
# CYKZ - 03
# le_ident
# CYKZ
# 03
# ['14199', '', '', '', '33.0']
# ['14199', '', '', '', '624.0\n14200', '', '', '', '640.0']
# CYKZ - 15
# le_ident
# CYKZ
# 15
# ['14200', '', '', '', '142.0']
# ['14199', '', '', '', '624.0\n14200', '', '', '', '640.0']
# CYKZ - 21
# he_ident
# CYKZ
# 21
# ['14199', '', '', '', '213.0']
# ['14199', '', '', '', '649.0\n14200', '', '', '', '638.0']
# CYKZ - 33
# he_ident
# CYKZ
# 33
# ['14200', '', '', '', '322.0']
# ['14199', '', '', '', '649.0\n14200', '', '', '', '638.0']
# CYLA - 04
# le_ident
# CYLA
# 04
# ['14201', '', '', 'NaN']
# ['14201', '', '', '', '72.0\n14202', '', '', '', '', 'NaN']
# CYLA - 22
# he_ident
# CYLA
# 22
# ['14201', '', '', 'NaN']
# ['14201', '', '', '', '119.0\n14202', '', '', '', '', '', 'NaN']
# CYLC - 16
# Data not found
# not_found
# CYLC
# 16
# CYLC - 34
# Data not found
# not_found
# CYLC
# 34
# CYLD - 05
# le_ident
# CYLD
# 05
# ['14204', '', '', '', '39.3']
# ['14204', '', '', '', '1460.0\n14205', '', '', '', '1470.0']
# CYLD - 10
# le_ident
# CYLD
# 10
# ['14205', '', '', '', '92.3']
# ['14204', '', '', '', '1460.0\n14205', '', '', '', '1470.0']
# CYLD - 23
# he_ident
# CYLD
# 23
# ['14204', '', '', '', '219.3']
# ['14204', '', '', '', '1447.0\n14205', '', '', '', '1421.0']
# CYLD - 28
# he_ident
# CYLD
# 28
# ['14205', '', '', '', '272.3']
# ['14204', '', '', '', '1447.0\n14205', '', '', '', '1421.0']
# CYLH - 08
# le_ident
# CYLH
# 08
# ['14206', '', '', 'NaN']
# ['14206', '', '', '', '825.0']
# CYLH - 26
# he_ident
# CYLH
# 26
# ['14206', '', '', 'NaN']
# ['14206', '', '', '', '828.0']
# CYLJ - 09
# le_ident
# CYLJ
# 09
# ['14208', '', '', '', '100.0']
# ['14208', '', '', '', '1576.0\n14209', '', '', '', '', '', '', 'NaN']
# CYLJ - 17
# le_ident
# CYLJ
# 17
# ['14209', '', '', '', '179.0']
# ['14208', '', '', '', '1576.0\n14209', '', '', '', '', '', '', 'NaN']
# CYLJ - 27
# he_ident
# CYLJ
# 27
# ['14208', '', '', '', '280.0']
# ['14208', '', '', '', '1576.0\n14209', '', '', '', '', '', '', 'NaN']
# CYLJ - 35
# he_ident
# CYLJ
# 35
# ['14209', '', '', '', '359.0']
# ['14208', '', '', '', '1576.0\n14209', '', '', '', '', '', '', 'NaN']
# CYLK - 08
# Data not found
# not_found
# CYLK
# 08
# CYLK - 26
# Data not found
# not_found
# CYLK
# 26
# CYLL - 08
# le_ident
# CYLL
# 08
# ['14211', '', '', '', '90.0']
# ['14211', '', '', '', '2193.0\n14212', '', '', '', '2187.0']
# CYLL - 26
# he_ident
# CYLL
# 26
# ['14211', '', '', '', '270.0']
# ['14211', '', '', '', '2158.0\n14212', '', '', '', '', '', '', 'NaN']
# CYLT - 05
# Data not found
# not_found
# CYLT
# 05
# CYLT - 23
# Data not found
# not_found
# CYLT
# 23
# CYLU - 16
# le_ident
# CYLU
# 16
# ['14217', '', '', 'NaN']
# ['14217', '', '', '', '157.0']
# CYLU - 34
# he_ident
# CYLU
# 34
# ['14217', '', '', 'NaN']
# ['14217', '', '', '', '215.0']
# CYLW - 16
# le_ident
# CYLW
# 16
# ['14218', '', '', '', '175.0']
# ['14218', '', '', '', '1421.0']
# CYLW - 34
# he_ident
# CYLW
# 34
# ['14218', '', '', '', '355.0']
# ['14218', '', '', '', '1370.0']
# CYMA - 06
# Data not found
# not_found
# CYMA
# 06
# CYMA - 24
# Data not found
# not_found
# CYMA
# 24
# CYMG - 05
# le_ident
# CYMG
# 05
# ['14222', '', '', '', '42.0']
# ['14222', '', '', '', '1171.0']
# CYMG - 23
# he_ident
# CYMG
# 23
# ['14222', '', '', '', '222.0']
# ['14222', '', '', '', '1198.0']
# CYMH - 11
# le_ident
# CYMH
# 11
# ['14223', '', '', 'NaN']
# ['14223', '', '', '', '38.0']
# CYMH - 29
# he_ident
# CYMH
# 29
# ['14223', '', '', 'NaN']
# ['14223', '', '', '', '28.0']
# CYMJ - 03
# le_ident
# CYMJ
# 03
# ['14224', '', '', '', '44.0']
# ['14224', '', '', '', '1891.0\n14225', '', '', '', '1882.0\n14226', '', '', '', '1891.0']
# CYMJ - 11L
# le_ident
# CYMJ
# 11L
# ['14225', '', '', '', '118.5']
# ['14224', '', '', '', '1891.0\n14225', '', '', '', '1882.0\n14226', '', '', '', '1891.0']
# CYMJ - 11R
# le_ident
# CYMJ
# 11R
# ['14226', '', '', '', '118.0']
# ['14224', '', '', '', '1891.0\n14225', '', '', '', '1882.0\n14226', '', '', '', '1891.0']
# CYMJ - 21
# he_ident
# CYMJ
# 21
# ['14224', '', '', '', '224.0']
# ['14224', '', '', '', '1873.0\n14225', '', '', '', '1880.0\n14226', '', '', '', '1892.0']
# CYMJ - 29L
# he_ident
# CYMJ
# 29L
# ['14226', '', '', '', '298.0']
# ['14224', '', '', '', '1873.0\n14225', '', '', '', '1880.0\n14226', '', '', '', '1892.0']
# CYMJ - 29R
# he_ident
# CYMJ
# 29R
# ['14225', '', '', '', '298.5']
# ['14224', '', '', '', '1873.0\n14225', '', '', '', '1880.0\n14226', '', '', '', '1892.0']
# CYMM - 07
# Data not found
# not_found
# CYMM
# 07
# CYMM - 25
# Data not found
# not_found
# CYMM
# 25
# CYMO - 06
# le_ident
# CYMO
# 06
# ['14229', '', '', '', '43.0']
# ['14229', '', '', '', '26.0\n14230', '', '', '', '30.0']
# CYMO - 14
# le_ident
# CYMO
# 14
# ['14230', '', '', '', '127.0']
# ['14229', '', '', '', '26.0\n14230', '', '', '', '30.0']
# CYMO - 24
# he_ident
# CYMO
# 24
# ['14229', '', '', '', '223.0']
# ['14229', '', '', '', '25.0\n14230', '', '', '', '26.0']
# CYMO - 32
# he_ident
# CYMO
# 32
# ['14230', '', '', '', '307.0']
# ['14229', '', '', '', '25.0\n14230', '', '', '', '26.0']
# CYMT - 05
# le_ident
# CYMT
# 05
# ['14231', '', '', '', '28.3']
# ['14231', '', '', '', '1262.0']
# CYMT - 23
# he_ident
# CYMT
# 23
# ['14231', '', '', '', '208.3']
# ['14231', '', '', '', '1270.0']
# CYMU - 03
# le_ident
# CYMU
# 03
# ['14232', '', '', 'NaN']
# ['14232', '', '', '', '246.0']
# CYMU - 21
# he_ident
# CYMU
# 21
# ['14232', '', '', 'NaN']
# ['14232', '', '', '', '250.0']
# CYMW - 03
# le_ident
# CYMW
# 03
# ['14233', '', '', '', '17.0']
# ['14233', '', '', '', '613.0']
# CYMW - 21
# he_ident
# CYMW
# 21
# ['14233', '', '', '', '197.0']
# ['14233', '', '', '', '656.0']
# CYMX - 06
# le_ident
# CYMX
# 06
# ['14234', '', '', '', '45.4']
# ['14234', '', '', '', '256.0\n14235', '', '', '', '247.0']
# CYMX - 11
# le_ident
# CYMX
# 11
# ['14235', '', '', '', '98.2']
# ['14234', '', '', '', '256.0\n14235', '', '', '', '247.0']
# CYMX - 24
# he_ident
# CYMX
# 24
# ['14234', '', '', '', '225.4']
# ['14234', '', '', '', '238.0\n14235', '', '', '', '270.0']
# CYMX - 29
# he_ident
# CYMX
# 29
# ['14235', '', '', '', '278.2']
# ['14234', '', '', '', '238.0\n14235', '', '', '', '270.0']
# CYNA - 14
# le_ident
# CYNA
# 14
# ['14237', '', '', '', '118.0']
# ['14237', '', '', '', '35.0']
# CYNA - 32
# he_ident
# CYNA
# 32
# ['14237', '', '', '', '298.0']
# ['14237', '', '', '', '39.0']
# CYNC - 10
# le_ident
# CYNC
# 10
# ['14238', '', '', 'NaN']
# ['14238', '', '', '', '30.0']
# CYNC - 28
# he_ident
# CYNC
# 28
# ['14238', '', '', 'NaN']
# ['14238', '', '', '', '66.0']
# CYND - 09
# le_ident
# CYND
# 09
# ['14239', '', '', '', '75.0']
# ['14239', '', '', '', '209.0']
# CYND - 27
# he_ident
# CYND
# 27
# ['14239', '', '', '', '255.0']
# ['14239', '', '', '', '211.0']
# CYNE - 05
# le_ident
# CYNE
# 05
# ['14240', '', '', 'NaN']
# ['14240', '', '', '', '723.0']
# CYNE - 23
# he_ident
# CYNE
# 23
# ['14240', '', '', 'NaN']
# ['14240', '', '', '', '734.0']
# CYNJ - 01
# le_ident
# CYNJ
# 01
# ['14242', '', '', 'NaN']
# ['14242', '', '', '', '34.0\n14243', '', '', '', '', 'NaN']
# CYNJ - 07
# le_ident
# CYNJ
# 07
# ['14243', '', '', 'NaN']
# ['14242', '', '', '', '34.0\n14243', '', '', '', '', 'NaN']
# CYNJ - 19
# he_ident
# CYNJ
# 19
# ['14242', '', '', 'NaN']
# ['14242', '', '', '', '34.0\n14243', '', '', '', '', 'NaN']
# CYNJ - 25
# he_ident
# CYNJ
# 25
# ['14243', '', '', 'NaN']
# ['14242', '', '', '', '34.0\n14243', '', '', '', '', 'NaN']
# CYNL - 15
# le_ident
# CYNL
# 15
# ['14244', '', '', 'NaN']
# ['14244', '', '', '', '1605.0']
# CYNL - 33
# he_ident
# CYNL
# 33
# ['14244', '', '', 'NaN']
# ['14244', '', '', '', '1589.0']
# CYNM - 15
# le_ident
# CYNM
# 15
# ['14245', '', '', '', '134.2']
# ['14245', '', '', '', '908.0']
# CYNM - 33
# he_ident
# CYNM
# 33
# ['14245', '', '', '', '314.2']
# ['14245', '', '', '', '918.0']
# CYOA - 02
# Data not found
# not_found
# CYOA
# 02
# CYOA - 20
# Data not found
# not_found
# CYOA
# 20
# CYOC - 03
# Data not found
# not_found
# CYOC
# 03
# CYOC - 21
# Data not found
# not_found
# CYOC
# 21
# CYOD - 04
# le_ident
# CYOD
# 04
# ['14250', '', '', '', '52.0']
# ['14250', '', '', '', '1772.0\n14251', '', '', '', '1772.0\n14252', '', '', '', '1771.0']
# CYOD - 13L
# le_ident
# CYOD
# 13L
# ['14251', '', '', '', '143.0']
# ['14250', '', '', '', '1772.0\n14251', '', '', '', '1772.0\n14252', '', '', '', '1771.0']
# CYOD - 13R
# le_ident
# CYOD
# 13R
# ['14252', '', '', '', '143.0']
# ['14250', '', '', '', '1772.0\n14251', '', '', '', '1772.0\n14252', '', '', '', '1771.0']
# CYOD - 22
# he_ident
# CYOD
# 22
# ['14250', '', '', '', '232.0']
# ['14250', '', '', '', '1767.0\n14251', '', '', '', '1775.0\n14252', '', '', '', '1773.0']
# CYOD - 31L
# he_ident
# CYOD
# 31L
# ['14252', '', '', '', '323.0']
# ['14250', '', '', '', '1767.0\n14251', '', '', '', '1775.0\n14252', '', '', '', '1773.0']
# CYOD - 31R
# he_ident
# CYOD
# 31R
# ['14251', '', '', '', '323.0']
# ['14250', '', '', '', '1767.0\n14251', '', '', '', '1775.0\n14252', '', '', '', '1773.0']
# CYOH - 05
# le_ident
# CYOH
# 05
# ['14254', '', '', 'NaN']
# ['14253', '', '', '', '', '', 'NaN\n14254', '', '', '', '646.0']
# CYOH - 23
# he_ident
# CYOH
# 23
# ['14254', '', '', 'NaN']
# ['14253', '', '', '', '', '', 'NaN\n14254', '', '', '', '663.0']
# CYOJ - 13
# le_ident
# CYOJ
# 13
# ['14255', '', '', '', '154.0']
# ['14255', '', '', '', '1109.0']
# CYOJ - 31
# he_ident
# CYOJ
# 31
# ['14255', '', '', '', '334.0']
# ['14255', '', '', '', '1098.0']
# CYOO - 04
# Data not found
# not_found
# CYOO
# 04
# CYOO - 12
# le_ident
# CYOO
# 12
# ['14257', '', '', '', '109.1']
# ['14256', '', '', '', '442.0\n14257', '', '', '', '459.0']
# CYOO - 22
# Data not found
# not_found
# CYOO
# 22
# CYOO - 30
# he_ident
# CYOO
# 30
# ['14257', '', '', '', '289.1']
# ['14256', '', '', '', '458.0\n14257', '', '', '', '447.0']
# CYOP - 09
# le_ident
# CYOP
# 09
# ['14258', '', '', '', '110.0']
# ['14258', '', '', '', '1759.0']
# CYOP - 27
# he_ident
# CYOP
# 27
# ['14258', '', '', '', '290.0']
# ['14258', '', '', '', '1759.0']
# CYOW - 04
# le_ident
# CYOW
# 04
# ['14260', '', '', '', '26.0']
# ['14260', '', '', '', '348.0\n14261', '', '', '', '373.0\n14262', '', '', '', '349.0']
# CYOW - 07
# le_ident
# CYOW
# 07
# ['14261', '', '', '', '57.2']
# ['14260', '', '', '', '348.0\n14261', '', '', '', '373.0\n14262', '', '', '', '349.0']
# CYOW - 14
# le_ident
# CYOW
# 14
# ['14262', '', '', '', '126.3']
# ['14260', '', '', '', '348.0\n14261', '', '', '', '373.0\n14262', '', '', '', '349.0']
# CYOW - 22
# he_ident
# CYOW
# 22
# ['14260', '', '', '', '206.0']
# ['14260', '', '', '', '335.0\n14261', '', '', '', '362.0\n14262', '', '', '', '371.0']
# CYOW - 25
# he_ident
# CYOW
# 25
# ['14261', '', '', '', '237.2']
# ['14260', '', '', '', '335.0\n14261', '', '', '', '362.0\n14262', '', '', '', '371.0']
# CYOW - 32
# he_ident
# CYOW
# 32
# ['14262', '', '', '', '306.3']
# ['14260', '', '', '', '335.0\n14261', '', '', '', '362.0\n14262', '', '', '', '371.0']
# CYPA - 08
# le_ident
# CYPA
# 08
# ['14263', '', '', '', '91.0']
# ['14263', '', '', '', '1405.0\n14264', '', '', '', '1402.0']
# CYPA - 16
# le_ident
# CYPA
# 16
# ['14264', '', '', '', '169.9']
# ['14263', '', '', '', '1405.0\n14264', '', '', '', '1402.0']
# CYPA - 26
# he_ident
# CYPA
# 26
# ['14263', '', '', '', '271.0']
# ['14263', '', '', '', '1401.0\n14264', '', '', '', '1396.0']
# CYPA - 34
# he_ident
# CYPA
# 34
# ['14264', '', '', '', '349.9']
# ['14263', '', '', '', '1401.0\n14264', '', '', '', '1396.0']
# CYPC - 02
# Data not found
# not_found
# CYPC
# 02
# CYPC - 20
# Data not found
# not_found
# CYPC
# 20
# CYPE - 04
# le_ident
# CYPE
# 04
# ['14267', '', '', '', '61.4']
# ['14267', '', '', '', '1873.0\n14268', '', '', '', '', '', '', 'NaN']
# CYPE - 22
# he_ident
# CYPE
# 22
# ['14267', '', '', '', '241.4']
# ['14267', '', '', '', '1861.0\n14268', '', '', '', '', '', '', 'NaN']
# CYPG - 01
# Data not found
# not_found
# CYPG
# 01
# CYPG - 08
# Data not found
# not_found
# CYPG
# 08
# CYPG - 13L
# le_ident
# CYPG
# 13L
# ['14271', '', '', '', '134.0']
# ['14269', '', '', '', '869.0\n14270', '', '', '', '866.0\n14271', '', '', '', '869.0\n14272', '', '', '', '878.0']
# CYPG - 13R
# le_ident
# CYPG
# 13R
# ['14272', '', '', '', '133.0']
# ['14269', '', '', '', '869.0\n14270', '', '', '', '866.0\n14271', '', '', '', '869.0\n14272', '', '', '', '878.0']
# CYPG - 19
# Data not found
# not_found
# CYPG
# 19
# CYPG - 26
# Data not found
# not_found
# CYPG
# 26
# CYPG - 31L
# he_ident
# CYPG
# 31L
# ['14272', '', '', '', '313.0']
# ['14269', '', '', '', '861.0\n14270', '', '', '', '861.0\n14271', '', '', '', '869.0\n14272', '', '', '', '885.0']
# CYPG - 31R
# he_ident
# CYPG
# 31R
# ['14271', '', '', '', '314.0']
# ['14269', '', '', '', '861.0\n14270', '', '', '', '861.0\n14271', '', '', '', '869.0\n14272', '', '', '', '885.0']
# CYPH - 07
# le_ident
# CYPH
# 07
# ['14273', '', '', 'NaN']
# ['14273', '', '', '', '74.0']
# CYPH - 25
# he_ident
# CYPH
# 25
# ['14273', '', '', 'NaN']
# ['14273', '', '', '', '74.0']
# CYPL - 09
# le_ident
# CYPL
# 09
# ['14277', '', '', '', '90.0']
# ['14277', '', '', '', '1267.0']
# CYPL - 27
# he_ident
# CYPL
# 27
# ['14277', '', '', '', '270.0']
# ['14277', '', '', '', '1227.0']
# CYPN - 11
# le_ident
# CYPN
# 11
# ['14279', '', '', '', '90.0']
# ['14279', '', '', '', '158.0']
# CYPN - 29
# he_ident
# CYPN
# 29
# ['14279', '', '', '', '270.0']
# ['14279', '', '', '', '158.0']
# CYPO - 11
# Data not found
# not_found
# CYPO
# 11
# CYPO - 29
# Data not found
# not_found
# CYPO
# 29
# CYPQ - 09
# le_ident
# CYPQ
# 09
# ['14281', '', '', '', '76.0']
# ['14281', '', '', '', '625.0\n14282', '', '', '', '', '', 'NaN']
# CYPQ - 27
# he_ident
# CYPQ
# 27
# ['14281', '', '', '', '256.0']
# ['14281', '', '', '', '628.0\n14282', '', '', '', '', '', 'NaN']
# CYPR - 13
# le_ident
# CYPR
# 13
# ['14283', '', '', '', '151.5']
# ['14283', '', '', '', '94.0']
# CYPR - 31
# he_ident
# CYPR
# 31
# ['14283', '', '', '', '331.5']
# ['14283', '', '', '', '116.0']
# CYPW - 09
# le_ident
# CYPW
# 09
# ['14288', '', '', '', '119.0']
# ['14288', '', '', '', '366.0']
# CYPW - 27
# he_ident
# CYPW
# 27
# ['14288', '', '', '', '299.0']
# ['14288', '', '', '', '425.0']
# CYPX - 01
# le_ident
# CYPX
# 01
# ['14289', '', '', '', '343.0']
# ['14289', '', '', '', '53.0']
# CYPX - 19
# he_ident
# CYPX
# 19
# ['14289', '', '', '', '163.0']
# ['14289', '', '', '', '74.0']
# CYPY - 03
# Data not found
# not_found
# CYPY
# 03
# CYPY - 21
# Data not found
# not_found
# CYPY
# 21
# CYQA - 18
# le_ident
# CYQA
# 18
# ['14293', '', '', '', '169.0']
# ['14292', '', '', '', '925.0\n14293', '', '', '', '909.0']
# CYQA - 36
# he_ident
# CYQA
# 36
# ['14293', '', '', '', '349.0']
# ['14292', '', '', '', '915.0\n14293', '', '', '', '918.0']
# CYQB - 06
# le_ident
# CYQB
# 06
# ['14294', '', '', '', '44.0']
# ['14294', '', '', '', '244.0\n14295', '', '', '', '239.0']
# CYQB - 12
# Data not found
# not_found
# CYQB
# 12
# CYQB - 24
# he_ident
# CYQB
# 24
# ['14294', '', '', '', '224.0']
# ['14294', '', '', '', '217.0\n14295', '', '', '', '231.0']
# CYQB - 30
# Data not found
# not_found
# CYQB
# 30
# CYQD - 13
# le_ident
# CYQD
# 13
# ['14296', '', '', '', '133.0']
# ['14296', '', '', '', '887.0']
# CYQD - 31
# he_ident
# CYQD
# 31
# ['14296', '', '', '', '313.0']
# ['14296', '', '', '', '876.0']
# CYQF - 11
# Data not found
# not_found
# CYQF
# 11
# CYQF - 16
# Data not found
# not_found
# CYQF
# 16
# CYQF - 29
# Data not found
# not_found
# CYQF
# 29
# CYQF - 34
# Data not found
# not_found
# CYQF
# 34
# CYQG - 07
# le_ident
# CYQG
# 07
# ['14299', '', '', '', '62.1']
# ['14299', '', '', '', '621.0\n14300', '', '', '', '622.0']
# CYQG - 12
# le_ident
# CYQG
# 12
# ['14300', '', '', '', '115.5']
# ['14299', '', '', '', '621.0\n14300', '', '', '', '622.0']
# CYQG - 25
# he_ident
# CYQG
# 25
# ['14299', '', '', '', '242.1']
# ['14299', '', '', '', '598.0\n14300', '', '', '', '619.0']
# CYQG - 30
# he_ident
# CYQG
# 30
# ['14300', '', '', '', '295.5']
# ['14299', '', '', '', '598.0\n14300', '', '', '', '619.0']
# CYQH - 08
# le_ident
# CYQH
# 08
# ['14301', '', '', '', '109.0']
# ['14301', '', '', '', '2244.0']
# CYQH - 26
# he_ident
# CYQH
# 26
# ['14301', '', '', '', '289.0']
# ['14301', '', '', '', '2255.0']
# CYQI - 06
# le_ident
# CYQI
# 06
# ['14302', '', '', '', '42.1']
# ['14302', '', '', '', '135.0\n14303', '', '', '', '120.0']
# CYQI - 15
# le_ident
# CYQI
# 15
# ['14303', '', '', '', '133.2']
# ['14302', '', '', '', '135.0\n14303', '', '', '', '120.0']
# CYQI - 24
# he_ident
# CYQI
# 24
# ['14302', '', '', '', '222.1']
# ['14302', '', '', '', '110.0\n14303', '', '', '', '103.0']
# CYQI - 33
# he_ident
# CYQI
# 33
# ['14303', '', '', '', '313.2']
# ['14302', '', '', '', '110.0\n14303', '', '', '', '103.0']
# CYQK - 08
# le_ident
# CYQK
# 08
# ['14304', '', '', '', '77.0']
# ['14304', '', '', '', '1325.0']
# CYQK - 26
# he_ident
# CYQK
# 26
# ['14304', '', '', '', '257.0']
# ['14304', '', '', '', '1332.0']
# CYQL - 05
# Data not found
# not_found
# CYQL
# 05
# CYQL - 12
# Data not found
# not_found
# CYQL
# 12
# CYQL - 23
# Data not found
# not_found
# CYQL
# 23
# CYQL - 30
# Data not found
# not_found
# CYQL
# 30
# CYQM - 06
# le_ident
# CYQM
# 06
# ['14307', '', '', '', '44.0']
# ['14307', '', '', '', '223.0\n14308', '', '', '', '222.0']
# CYQM - 11
# le_ident
# CYQM
# 11
# ['14308', '', '', '', '89.0']
# ['14307', '', '', '', '223.0\n14308', '', '', '', '222.0']
# CYQM - 24
# he_ident
# CYQM
# 24
# ...
# KLYH - 35
# he_ident
# KLYH
# 35
# ['22949', '', '', '', '341.1']
# ['22948', '', '', '', '938.0\n22949', '', '', '', '918.0']
# KLZU - 07
# le_ident
# KLZU
# 07
# ['22955', '', '', '', '64.0']
# ['22955', '', '', '', '1061.0']
# KLZU - 25
# he_ident
# KLZU
# 25
# ['22955', '', '', '', '244.0']
# ['22955', '', '', '', '1031.0']
# KMAE - 07
# le_ident
# KMAE
# 07
# ['23037', '', '', '', '90.0']
# ['23037', '', '', '', '244.0\n23038', '', '', '', '249.0']
# KMAE - 12
# le_ident
# KMAE
# 12
# ['23038', '', '', '', '135.0']
# ['23037', '', '', '', '244.0\n23038', '', '', '', '249.0']
# KMAE - 25
# he_ident
# KMAE
# 25
# ['23037', '', '', '', '270.0']
# ['23037', '', '', '', '253.0\n23038', '', '', '', '253.0']
# KMAE - 30
# he_ident
# KMAE
# 30
# ['23038', '', '', '', '315.0']
# ['23037', '', '', '', '253.0\n23038', '', '', '', '253.0']
# KMAF - 04
# le_ident
# KMAF
# 04
# ['23039', '', '', '', '54.0']
# ['23039', '', '', '', '2850.0\n23040', '', '', '', '2869.0\n23041', '', '', '', '2863.0\n23042', '', '', '', '2871.0']
# KMAF - 10
# le_ident
# KMAF
# 10
# ['23040', '', '', '', '114.0']
# ['23039', '', '', '', '2850.0\n23040', '', '', '', '2869.0\n23041', '', '', '', '2863.0\n23042', '', '', '', '2871.0']
# KMAF - 16L
# le_ident
# KMAF
# 16L
# ['23041', '', '', '', '177.0']
# ['23039', '', '', '', '2850.0\n23040', '', '', '', '2869.0\n23041', '', '', '', '2863.0\n23042', '', '', '', '2871.0']
# KMAF - 16R
# le_ident
# KMAF
# 16R
# ['23042', '', '', '', '175.0']
# ['23039', '', '', '', '2850.0\n23040', '', '', '', '2869.0\n23041', '', '', '', '2863.0\n23042', '', '', '', '2871.0']
# KMAF - 22
# he_ident
# KMAF
# 22
# ['23039', '', '', '', '234.0']
# ['23039', '', '', '', '2853.0\n23040', '', '', '', '2854.0\n23041', '', '', '', '2846.0\n23042', '', '', '', '2850.0']
# KMAF - 28
# he_ident
# KMAF
# 28
# ['23040', '', '', '', '294.0']
# ['23039', '', '', '', '2853.0\n23040', '', '', '', '2854.0\n23041', '', '', '', '2846.0\n23042', '', '', '', '2850.0']
# KMAF - 34L
# he_ident
# KMAF
# 34L
# ['23042', '', '', '', '355.0']
# ['23039', '', '', '', '2853.0\n23040', '', '', '', '2854.0\n23041', '', '', '', '2846.0\n23042', '', '', '', '2850.0']
# KMAF - 34R
# he_ident
# KMAF
# 34R
# ['23041', '', '', '', '357.0']
# ['23039', '', '', '', '2853.0\n23040', '', '', '', '2854.0\n23041', '', '', '', '2846.0\n23042', '', '', '', '2850.0']
# KMBL - 09
# le_ident
# KMBL
# 09
# ['23058', '', '', '', '91.0']
# ['23058', '', '', '', '616.0\n23059', '', '', '', '618.0']
# KMBL - 18
# le_ident
# KMBL
# 18
# ['23059', '', '', '', '181.0']
# ['23058', '', '', '', '616.0\n23059', '', '', '', '618.0']
# KMBL - 27
# he_ident
# KMBL
# 27
# ['23058', '', '', '', '271.0']
# ['23058', '', '', '', '621.0\n23059', '', '', '', '621.0']
# KMBL - 36
# he_ident
# KMBL
# 36
# ['23059', '', '', '', '1.0']
# ['23058', '', '', '', '621.0\n23059', '', '', '', '621.0']
# KMBS - 05
# le_ident
# KMBS
# 05
# ['23061', '', '', '', '45.5']
# ['23061', '', '', '', '666.0\n23062', '', '', '', '668.0']
# KMBS - 14
# le_ident
# KMBS
# 14
# ['23062', '', '', '', '135.7']
# ['23061', '', '', '', '666.0\n23062', '', '', '', '668.0']
# KMBS - 23
# he_ident
# KMBS
# 23
# ['23061', '', '', '', '225.5']
# ['23061', '', '', '', '650.0\n23062', '', '', '', '660.0']
# KMBS - 32
# he_ident
# KMBS
# 32
# ['23062', '', '', '', '315.7']
# ['23061', '', '', '', '650.0\n23062', '', '', '', '660.0']
# KMCC - 16
# le_ident
# KMCC
# 16
# ['23067', '', '', '', '179.7']
# ['23067', '', '', '', '75.0']
# KMCC - 34
# he_ident
# KMCC
# 34
# ['23067', '', '', '', '359.7']
# ['23067', '', '', '', '70.0']
# KMCE - 12
# le_ident
# KMCE
# 12
# ['23069', '', '', '', '138.6']
# ['23069', '', '', '', '155.0']
# KMCE - 30
# he_ident
# KMCE
# 30
# ['23069', '', '', '', '318.6']
# ['23069', '', '', '', '155.0']
# KMCF - 04
# le_ident
# KMCF
# 04
# ['23070', '', '', '', '40.5']
# ['23070', '', '', '', '8.0']
# KMCF - 22
# he_ident
# KMCF
# 22
# ['23070', '', '', '', '220.5']
# ['23070', '', '', '', '14.0']
# KMCI - 01L
# le_ident
# KMCI
# 01L
# ['23071', '', '', '', '12.9']
# ['23071', '', '', '', '1011.0\n23072', '', '', '', '1016.0\n23073', '', '', '', '1014.0']
# KMCI - 01R
# le_ident
# KMCI
# 01R
# ['23072', '', '', '', '12.9']
# ['23071', '', '', '', '1011.0\n23072', '', '', '', '1016.0\n23073', '', '', '', '1014.0']
# KMCI - 09
# le_ident
# KMCI
# 09
# ['23073', '', '', '', '96.1']
# ['23071', '', '', '', '1011.0\n23072', '', '', '', '1016.0\n23073', '', '', '', '1014.0']
# KMCI - 19L
# he_ident
# KMCI
# 19L
# ['23072', '', '', '', '192.9']
# ['23071', '', '', '', '', '977.0\n23072', '', '', '', '', '978.0\n23073', '', '', '', '1026.0']
# KMCI - 19R
# he_ident
# KMCI
# 19R
# ['23071', '', '', '', '192.9']
# ['23071', '', '', '', '', '977.0\n23072', '', '', '', '', '978.0\n23073', '', '', '', '1026.0']
# KMCI - 27
# he_ident
# KMCI
# 27
# ['23073', '', '', '', '276.1']
# ['23071', '', '', '', '', '977.0\n23072', '', '', '', '', '978.0\n23073', '', '', '', '1026.0']
# KMCK - 04
# le_ident
# KMCK
# 04
# ['23074', '', '', '', '46.0']
# ['23074', '', '', '', '2563.0\n23075', '', '', '', '2583.0\n23076', '', '', '', '2558.0']
# KMCK - 12
# le_ident
# KMCK
# 12
# ['23075', '', '', '', '131.5']
# ['23074', '', '', '', '2563.0\n23075', '', '', '', '2583.0\n23076', '', '', '', '2558.0']
# KMCK - 17
# le_ident
# KMCK
# 17
# ['23076', '', '', '', '181.5']
# ['23074', '', '', '', '2563.0\n23075', '', '', '', '2583.0\n23076', '', '', '', '2558.0']
# KMCK - 22
# he_ident
# KMCK
# 22
# ['23074', '', '', '', '226.0']
# ['23074', '', '', '', '2556.0\n23075', '', '', '', '2546.0\n23076', '', '', '', '2560.0']
# KMCK - 30
# he_ident
# KMCK
# 30
# ['23075', '', '', '', '311.5']
# ['23074', '', '', '', '2556.0\n23075', '', '', '', '2546.0\n23076', '', '', '', '2560.0']
# KMCK - 35
# he_ident
# KMCK
# 35
# ['23076', '', '', '', '1.5']
# ['23074', '', '', '', '2556.0\n23075', '', '', '', '2546.0\n23076', '', '', '', '2560.0']
# KMCN - 05
# le_ident
# KMCN
# 05
# ['23077', '', '', '', '48.0']
# ['23077', '', '', '', '331.0\n23078', '', '', '', '354.0']
# KMCN - 13
# le_ident
# KMCN
# 13
# ['23078', '', '', '', '130.0']
# ['23077', '', '', '', '331.0\n23078', '', '', '', '354.0']
# KMCN - 23
# he_ident
# KMCN
# 23
# ['23077', '', '', '', '228.0']
# ['23077', '', '', '', '354.0\n23078', '', '', '', '346.0']
# KMCN - 31
# he_ident
# KMCN
# 31
# ['23078', '', '', '', '310.0']
# ['23077', '', '', '', '354.0\n23078', '', '', '', '346.0']
# KMCO - 17L
# le_ident
# KMCO
# 17L
# ['23079', '', '', '', '179.5']
# ['23079', '', '', '', '90.0\n23080', '', '', '', '90.0\n23081', '', '', '', '93.0\n23082', '', '', '', '93.0']
# KMCO - 17R
# le_ident
# KMCO
# 17R
# ['23080', '', '', '', '179.0']
# ['23079', '', '', '', '90.0\n23080', '', '', '', '90.0\n23081', '', '', '', '93.0\n23082', '', '', '', '93.0']
# KMCO - 18L
# le_ident
# KMCO
# 18L
# ['23081', '', '', '', '179.0']
# ['23079', '', '', '', '90.0\n23080', '', '', '', '90.0\n23081', '', '', '', '93.0\n23082', '', '', '', '93.0']
# KMCO - 18R
# le_ident
# KMCO
# 18R
# ['23082', '', '', '', '179.0']
# ['23079', '', '', '', '90.0\n23080', '', '', '', '90.0\n23081', '', '', '', '93.0\n23082', '', '', '', '93.0']
# KMCO - 35L
# he_ident
# KMCO
# 35L
# ['23080', '', '', '', '359.0']
# ['23079', '', '', '', '90.0\n23080', '', '', '', '87.0\n23081', '', '', '', '91.0\n23082', '', '', '', '91.0']
# KMCO - 35R
# he_ident
# KMCO
# 35R
# ['23079', '', '', '', '359.5']
# ['23079', '', '', '', '90.0\n23080', '', '', '', '87.0\n23081', '', '', '', '91.0\n23082', '', '', '', '91.0']
# KMCO - 36L
# he_ident
# KMCO
# 36L
# ['23082', '', '', '', '359.0']
# ['23079', '', '', '', '90.0\n23080', '', '', '', '87.0\n23081', '', '', '', '91.0\n23082', '', '', '', '91.0']
# KMCO - 36R
# he_ident
# KMCO
# 36R
# ['23081', '', '', '', '359.0']
# ['23079', '', '', '', '90.0\n23080', '', '', '', '87.0\n23081', '', '', '', '91.0\n23082', '', '', '', '91.0']
# KMCW - 12
# le_ident
# KMCW
# 12
# ['23083', '', '', '', '124.9']
# ['23083', '', '', '', '1209.0\n23084', '', '', '', '1213.0']
# KMCW - 18
# le_ident
# KMCW
# 18
# ['23084', '', '', '', '179.9']
# ['23083', '', '', '', '1209.0\n23084', '', '', '', '1213.0']
# KMCW - 30
# he_ident
# KMCW
# 30
# ['23083', '', '', '', '304.9']
# ['23083', '', '', '', '1193.0\n23084', '', '', '', '1193.0']
# KMCW - 36
# he_ident
# KMCW
# 36
# ['23084', '', '', '', '359.9']
# ['23083', '', '', '', '1193.0\n23084', '', '', '', '1193.0']
# KMDT - 13
# le_ident
# KMDT
# 13
# ['23098', '', '', '', '116.8']
# ['23098', '', '', '', '308.0']
# KMDT - 31
# he_ident
# KMDT
# 31
# ['23098', '', '', '', '296.8']
# ['23098', '', '', '', '308.0']
# KMDW - 04L
# le_ident
# KMDW
# 04L
# ['23099', '', '', '', '43.0']
# ['23099', '', '', '', '617.0\n23100', '', '', '', '619.0\n23101', '', '', '', '608.0\n23102', '', '', '', '606.0\n23103', '', '', '', '607.0']
# KMDW - 04R
# le_ident
# KMDW
# 04R
# ['23100', '', '', '', '43.0']
# ['23099', '', '', '', '617.0\n23100', '', '', '', '619.0\n23101', '', '', '', '608.0\n23102', '', '', '', '606.0\n23103', '', '', '', '607.0']
# KMDW - 13C
# le_ident
# KMDW
# 13C
# ['23101', '', '', '', '134.0']
# ['23099', '', '', '', '617.0\n23100', '', '', '', '619.0\n23101', '', '', '', '608.0\n23102', '', '', '', '606.0\n23103', '', '', '', '607.0']
# KMDW - 13L
# le_ident
# KMDW
# 13L
# ['23102', '', '', '', '134.0']
# ['23099', '', '', '', '617.0\n23100', '', '', '', '619.0\n23101', '', '', '', '608.0\n23102', '', '', '', '606.0\n23103', '', '', '', '607.0']
# KMDW - 13R
# le_ident
# KMDW
# 13R
# ['23103', '', '', '', '134.0']
# ['23099', '', '', '', '617.0\n23100', '', '', '', '619.0\n23101', '', '', '', '608.0\n23102', '', '', '', '606.0\n23103', '', '', '', '607.0']
# KMDW - 22L
# he_ident
# KMDW
# 22L
# ['23100', '', '', '', '223.0']
# ['23099', '', '', '', '606.0\n23100', '', '', '', '606.0\n23101', '', '', '', '612.0\n23102', '', '', '', '608.0\n23103', '', '', '', '613.0']
# KMDW - 22R
# he_ident
# KMDW
# 22R
# ['23099', '', '', '', '223.0']
# ['23099', '', '', '', '606.0\n23100', '', '', '', '606.0\n23101', '', '', '', '612.0\n23102', '', '', '', '608.0\n23103', '', '', '', '613.0']
# KMDW - 31C
# he_ident
# KMDW
# 31C
# ['23101', '', '', '', '314.0']
# ['23099', '', '', '', '606.0\n23100', '', '', '', '606.0\n23101', '', '', '', '612.0\n23102', '', '', '', '608.0\n23103', '', '', '', '613.0']
# KMDW - 31L
# he_ident
# KMDW
# 31L
# ['23103', '', '', '', '314.0']
# ['23099', '', '', '', '606.0\n23100', '', '', '', '606.0\n23101', '', '', '', '612.0\n23102', '', '', '', '608.0\n23103', '', '', '', '613.0']
# KMDW - 31R
# he_ident
# KMDW
# 31R
# ['23102', '', '', '', '314.0']
# ['23099', '', '', '', '606.0\n23100', '', '', '', '606.0\n23101', '', '', '', '612.0\n23102', '', '', '', '608.0\n23103', '', '', '', '613.0']
# KMEI - 01
# le_ident
# KMEI
# 01
# ['23108', '', '', '', '9.0']
# ['23108', '', '', '', '287.0\n23109', '', '', '', '290.0']
# KMEI - 04
# le_ident
# KMEI
# 04
# ['23109', '', '', '', '44.0']
# ['23108', '', '', '', '287.0\n23109', '', '', '', '290.0']
# KMEI - 19
# he_ident
# KMEI
# 19
# ['23108', '', '', '', '189.0']
# ['23108', '', '', '', '293.0\n23109', '', '', '', '297.0']
# KMEI - 22
# he_ident
# KMEI
# 22
# ['23109', '', '', '', '224.0']
# ['23108', '', '', '', '293.0\n23109', '', '', '', '297.0']
# KMEM - 09
# le_ident
# KMEM
# 09
# ['23112', '', '', '', '92.0']
# ['23112', '', '', '', '253.0\n23113', '', '', '', '271.0\n23114', '', '', '', '278.0\n23115', '', '', '', '288.0']
# KMEM - 18C
# le_ident
# KMEM
# 18C
# ['23113', '', '', '', '179.0']
# ['23112', '', '', '', '253.0\n23113', '', '', '', '271.0\n23114', '', '', '', '278.0\n23115', '', '', '', '288.0']
# KMEM - 18L
# le_ident
# KMEM
# 18L
# ['23114', '', '', '', '179.0']
# ['23112', '', '', '', '253.0\n23113', '', '', '', '271.0\n23114', '', '', '', '278.0\n23115', '', '', '', '288.0']
# KMEM - 18R
# le_ident
# KMEM
# 18R
# ['23115', '', '', '', '179.0']
# ['23112', '', '', '', '253.0\n23113', '', '', '', '271.0\n23114', '', '', '', '278.0\n23115', '', '', '', '288.0']
# KMEM - 27
# he_ident
# KMEM
# 27
# ['23112', '', '', '', '272.0']
# ['23112', '', '', '', '292.0\n23113', '', '', '', '341.0\n23114', '', '', '', '335.0\n23115', '', '', '', '321.0']
# KMEM - 36C
# he_ident
# KMEM
# 36C
# ['23113', '', '', '', '359.0']
# ['23112', '', '', '', '292.0\n23113', '', '', '', '341.0\n23114', '', '', '', '335.0\n23115', '', '', '', '321.0']
# KMEM - 36L
# he_ident
# KMEM
# 36L
# ['23115', '', '', '', '359.0']
# ['23112', '', '', '', '292.0\n23113', '', '', '', '341.0\n23114', '', '', '', '335.0\n23115', '', '', '', '321.0']
# KMEM - 36R
# he_ident
# KMEM
# 36R
# ['23114', '', '', '', '359.0']
# ['23112', '', '', '', '292.0\n23113', '', '', '', '341.0\n23114', '', '', '', '335.0\n23115', '', '', '', '321.0']
# KMFD - 05
# le_ident
# KMFD
# 05
# ['23124', '', '', '', '46.9']
# ['23124', '', '', '', '1287.0\n23125', '', '', '', '1245.0']
# KMFD - 14
# le_ident
# KMFD
# 14
# ['23125', '', '', '', '136.9']
# ['23124', '', '', '', '1287.0\n23125', '', '', '', '1245.0']
# KMFD - 23
# he_ident
# KMFD
# 23
# ['23124', '', '', '', '226.9']
# ['23124', '', '', '', '1276.0\n23125', '', '', '', '1290.0']
# KMFD - 32
# he_ident
# KMFD
# 32
# ['23125', '', '', '', '316.9']
# ['23124', '', '', '', '1276.0\n23125', '', '', '', '1290.0']
# KMFE - 13
# le_ident
# KMFE
# 13
# ['23126', '', '', '', '140.6']
# ['23126', '', '', '', '107.0\n23127', '', '', '', '104.0']
# KMFE - 18
# le_ident
# KMFE
# 18
# ['23127', '', '', '', '188.7']
# ['23126', '', '', '', '107.0\n23127', '', '', '', '104.0']
# KMFE - 31
# he_ident
# KMFE
# 31
# ['23126', '', '', '', '320.6']
# ['23126', '', '', '', '102.0\n23127', '', '', '', '', '96.0']
# KMFE - 36
# he_ident
# KMFE
# 36
# ['23127', '', '', '', '8.7']
# ['23126', '', '', '', '102.0\n23127', '', '', '', '', '96.0']
# KMFI - 04
# le_ident
# KMFI
# 04
# ['23128', '', '', '', '46.9']
# ['23128', '', '', '', '1252.0\n23129', '', '', '', '1277.0']
# KMFI - 16
# le_ident
# KMFI
# 16
# ['23129', '', '', '', '158.6']
# ['23128', '', '', '', '1252.0\n23129', '', '', '', '1277.0']
# KMFI - 22
# he_ident
# KMFI
# 22
# ['23128', '', '', '', '226.9']
# ['23128', '', '', '', '1248.0\n23129', '', '', '', '1254.0']
# KMFI - 34
# he_ident
# KMFI
# 34
# ['23129', '', '', '', '338.6']
# ['23128', '', '', '', '1248.0\n23129', '', '', '', '1254.0']
# KMFR - 09
# le_ident
# KMFR
# 09
# ['23130', '', '', '', '113.0']
# ['23130', '', '', '', '1308.0\n23131', '', '', '', '1298.0']
# KMFR - 14
# le_ident
# KMFR
# 14
# ['23131', '', '', '', '159.0']
# ['23130', '', '', '', '1308.0\n23131', '', '', '', '1298.0']
# KMFR - 27
# he_ident
# KMFR
# 27
# ['23130', '', '', '', '293.0']
# ['23130', '', '', '', '1320.0\n23131', '', '', '', '1335.0']
# KMFR - 32
# he_ident
# KMFR
# 32
# ['23131', '', '', '', '339.0']
# ['23130', '', '', '', '1320.0\n23131', '', '', '', '1335.0']
# KMGC - 02
# le_ident
# KMGC
# 02
# ['23133', '', '', '', '20.0']
# ['23133', '', '', '', '655.0']
# KMGC - 20
# he_ident
# KMGC
# 20
# ['23133', '', '', '', '200.0']
# ['23133', '', '', '', '642.0']
# KMGE - 11
# le_ident
# KMGE
# 11
# ['23134', '', '', '', '106.2']
# ['23134', '', '', '', '1068.0\n23135', '', '', '', '', '', '', 'NaN']
# KMGE - 29
# he_ident
# KMGE
# 29
# ['23134', '', '', '', '286.2']
# ['23134', '', '', '', '989.0\n23135', '', '', '', '', '', 'NaN']
# KMGJ - 03
# Data not found
# not_found
# KMGJ
# 03
# KMGJ - 08
# Data not found
# not_found
# KMGJ
# 08
# KMGJ - 21
# Data not found
# not_found
# KMGJ
# 21
# KMGJ - 26
# he_ident
# KMGJ
# 26
# ['23139', '', '', '', '246.0']
# ['23138', '', '', '', '370.0\n23139', '', '', '', '364.0']
# KMGM - 03
# le_ident
# KMGM
# 03
# ['23140', '', '', '', '33.0']
# ['23140', '', '', '', '221.0\n23141', '', '', '', '219.0']
# KMGM - 10
# le_ident
# KMGM
# 10
# ['23141', '', '', '', '96.0']
# ['23140', '', '', '', '221.0\n23141', '', '', '', '219.0']
# KMGM - 21
# he_ident
# KMGM
# 21
# ['23140', '', '', '', '213.0']
# ['23140', '', '', '', '186.0\n23141', '', '', '', '195.0']
# KMGM - 28
# he_ident
# KMGM
# 28
# ['23141', '', '', '', '276.0']
# ['23140', '', '', '', '186.0\n23141', '', '', '', '195.0']
# KMGW - 05
# le_ident
# KMGW
# 05
# ['23145', '', '', '', '44.9']
# ['23145', '', '', '', '1241.0\n23146', '', '', '', '1236.0\n23147', '', '', '', '', '', '', 'NaN']
# KMGW - 18
# le_ident
# KMGW
# 18
# ['23146', '', '', '', '172.4']
# ['23145', '', '', '', '1241.0\n23146', '', '', '', '1236.0\n23147', '', '', '', '', '', '', 'NaN']
# KMGW - 23
# he_ident
# KMGW
# 23
# ['23145', '', '', '', '224.9\n23147', '', '', '', '225.0']
# ['23145', '', '', '', '1241.0\n23146', '', '', '', '1244.0\n23147', '', '', '', '', '', '', 'NaN']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-189-8511275ae7fd> in <module>
#      49         except:
#      50             rte = OAData.loc[(OAData["airport_ident"] == row.airportICAO) & (OAData[identifier] == row.rwyIdent), cursor].to_string().split(" ")[3]
# ---> 51         rte = float(rte)*0.3048
#      52         database.loc[(database["airportICAO"] == row.airportICAO) & (database["rwyIdent"] == row.rwyIdent), "rwyThresElevation"] = rte
#      53
#
# ValueError: could not convert string to float: '1241.0\n23147'

# %%
data_not_found
# Out:
# ['BGJN|07',
#  'BGJN|25',
#  'BGQQ|18',
#  'BGQQ|36',
#  'BGSS|14',
#  'BGSS|32',
#  'BGUQ|16',
#  'BGUQ|34',
#  'BIEG|04',
#  'BIEG|22',
#  'BIGR|18',
#  'BIGR|36',
#  'BIHU|03',
#  'BIHU|21',
#  'BIKF|02',
#  'BIKF|11',
#  'BIKF|20',
#  'BIKF|29',
#  'BIVM|04',
#  'BIVM|13',
#  'BIVM|22',
#  'BIVM|31',
#  'CBW4|15',
#  'CBW4|33',
#  'CCE4|15',
#  'CCE4|33',
#  'CEM3|09',
#  'CEM3|27',
#  'CYAS|04',
#  'CYAS|22',
#  'CYBK|16',
#  'CYBK|34',
#  'CYBL|11',
#  'CYBL|29',
#  'CYCA|08',
#  'CYCA|26',
#  'CYCB|13',
#  'CYCB|31',
#  'CYCO|12',
#  'CYCO|30',
#  'CYCS|12',
#  'CYCS|30',
#  'CYCY|02',
#  'CYCY|20',
#  'CYDA|02',
#  'CYDA|20',
#  'CYDP|05',
#  'CYDP|23',
#  'CYEK|15',
#  'CYEK|33',
#  'CYEU|10',
#  'CYEU|28',
#  'CYFB|17',
#  'CYFB|35',
#  'CYFS|13',
#  'CYFS|31',
#  'CYGP|11',
#  'CYGP|29',
#  'CYGT|15',
#  'CYGT|33',
#  'CYGV|09',
#  'CYGV|27',
#  'CYGZ|14',
#  'CYGZ|32',
#  'CYHA|01',
#  'CYHA|19',
#  'CYHI|06',
#  'CYHI|24',
#  'CYHK|13',
#  'CYHK|31',
#  'CYHY|13',
#  'CYHY|31',
#  'CYIK|08',
#  'CYIK|26',
#  'CYIO|02',
#  'CYIO|20',
#  'CYKA|08',
#  'CYKA|26',
#  'CYKL|18',
#  'CYKL|36',
#  'CYKY|08',
#  'CYKY|26',
#  'CYLC|16',
#  'CYLC|34',
#  'CYLK|08',
#  'CYLK|26',
#  'CYLT|05',
#  'CYLT|23',
#  'CYMA|06',
#  'CYMA|24',
#  'CYMM|07',
#  'CYMM|25',
#  'CYOA|02',
#  'CYOA|20',
#  'CYOC|03',
#  'CYOC|21',
#  'CYOO|04',
#  'CYOO|22',
#  'CYPC|02',
#  'CYPC|20',
#  'CYPG|01',
#  'CYPG|08',
#  'CYPG|19',
#  'CYPG|26',
#  'CYPO|11',
#  'CYPO|29',
#  'CYPY|03',
#  'CYPY|21',
#  'CYQB|12',
#  'CYQB|30',
#  'CYQF|11',
#  'CYQF|16',
#  'CYQF|29',
#  'CYQF|34',
#  'CYQL|05',
#  'CYQL|12',
#  'CYQL|23',
#  'CYQL|30',
#  'CYQV|03',
#  'CYQV|21',
#  'CYQY|01',
#  'CYQY|07',
#  'CYQY|19',
#  'CYQY|25',
#  'CYRB|17',
#  'CYRB|35',
#  'CYRT|13',
#  'CYRT|31',
#  'CYSM|02',
#  'CYSM|11',
#  'CYSM|20',
#  'CYSM|29',
#  'CYSR|11',
#  'CYSR|29',
#  'CYSY|08',
#  'CYSY|26',
#  'CYTE|13',
#  'CYTE|31',
#  'CYTH|06',
#  'CYTH|15',
#  'CYTH|24',
#  'CYTH|33',
#  'CYTQ|06',
#  'CYTQ|24',
#  'CYUT|16',
#  'CYUT|34',
#  'CYUX|12',
#  'CYUX|30',
#  'CYVM|03',
#  'CYVM|21',
#  'CYVR|12',
#  'CYVR|30',
#  'CYVT|11',
#  'CYVT|29',
#  'CYXN|15',
#  'CYXN|33',
#  'CYXP|06',
#  'CYXP|24',
#  'CYXY|13L',
#  'CYXY|13R',
#  'CYXY|31L',
#  'CYXY|31R',
#  'CYYC|07',
#  'CYYC|10',
#  'CYYC|16',
#  'CYYC|25',
#  'CYYC|28',
#  'CYYC|34',
#  'CYYE|03',
#  'CYYE|21',
#  'CYYH|15',
#  'CYYH|33',
#  'CYYJ|02',
#  'CYYJ|13',
#  'CYYJ|20',
#  'CYYJ|31',
#  'CYYR|16',
#  'CYYR|34',
#  'CYZF|09',
#  'CYZF|15',
#  'CYZF|27',
#  'CYZF|33',
#  'CYZG|03',
#  'CYZG|21',
#  'CYZP|12',
#  'CYZP|30',
#  'CYZT|07',
#  'CYZT|25',
#  'CZBB|12',
#  'CZBB|30',
#  'CZBM|05L',
#  'CZBM|23R',
#  'DABB|01',
#  'DABB|19',
#  'DAUU|02',
#  'DAUU|20',
#  'DAUZ|14',
#  'DAUZ|32',
#  'DFFD|04L',
#  'DFFD|22R',
#  'DNZA|06',
#  'DNZA|24',
#  'EBBR|02',
#  'EBBR|20',
#  'EBCI|07',
#  'EBCI|25',
#  'EBLG|05L',
#  'EBLG|05R',
#  'EBLG|23L',
#  'EBLG|23R',
#  'EDDB|07',
#  'EDDB|25',
#  'EDDE|10',
#  'EDDE|28',
#  'EDFE|09',
#  'EDFE|27',
#  'EDFZ|08',
#  'EDFZ|26',
#  'EDLE|07',
#  'EDLE|25',
#  'EDMS|10',
#  'EDMS|28',
#  'EDQM|09',
#  'EDQM|27',
#  'EGAB|15',
#  'EGAB|33',
#  'EGDX|08',
#  'EGDX|26',
#  'EGDY|09',
#  'EGDY|27',
#  'EGGW|08',
#  'EGGW|26',
#  'EGJJ|09',
#  'EGJJ|27',
#  'EGMC|06',
#  'EGMC|24',
#  'EGNC|07',
#  'EGNC|25',
#  'EGPA|15',
#  'EGPA|33',
#  'EGPE|12',
#  'EGPE|30',
#  'EGPK|13',
#  'EGPK|31',
#  'EGQL|09',
#  'EGQL|27',
#  'EGUN|11',
#  'EGUN|29',
#  'EGUY|08',
#  'EGUY|26',
#  'EGVN|08',
#  'EGVN|26',
#  'EHKD|04',
#  'EHKD|22',
#  'EHLW|06',
#  'EHLW|24',
#  'EHTW|06',
#  'EHTW|24',
#  'EICK|17',
#  'EICK|35',
#  'EIDW|10',
#  'EIDW|28',
#  'EIKN|09',
#  'EIKN|27',
#  'EISG|11',
#  'EISG|29',
#  'EKSN|09',
#  'EKSN|27',
#  'EKSP|11L',
#  'EKSP|11R',
#  'EKSP|29L',
#  'EKSP|29R',
#  'EKVG|13',
#  'EKVG|31',
#  'ENBN|04',
#  'ENBN|22',
#  'ENCN|04',
#  'ENCN|22',
#  'ENHD|14',
#  'ENHD|32',
#  'ENHF|05',
#  'ENHF|23',
#  'ENKR|06',
#  'ENKR|24',
#  'ENNA|17',
#  'ENNA|35',
#  'ENRA|14',
#  'ENRA|32',
#  'ENRO|14',
#  'ENRO|32',
#  'ENRS|03',
#  'ENRS|21',
#  'ENSD|09',
#  'ENSD|27',
#  'ENSK|09',
#  'ENSK|27',
#  'ENSO|15',
#  'ENSO|33',
#  'ENSR|15',
#  'ENSR|33',
#  'ENTC|01',
#  'ENTC|19',
#  'EPLL|07',
#  'EPLL|25',
#  'EPPO|11',
#  'EPPO|29',
#  'ETNL|10',
#  'ETNL|28',
#  'ETNU|09',
#  'ETNU|27',
#  'EYVI|02',
#  'EYVI|20',
#  'FAGM|11',
#  'FAGM|17',
#  'FAGM|29',
#  'FAGM|35',
#  'FAJS|03L',
#  'FAJS|03R',
#  'FAJS|21L',
#  'FAJS|21R',
#  'FALA|06R',
#  'FALA|24L',
#  'FAPE|10',
#  'FAPE|28',
#  'FAUP|01',
#  'FAUP|19',
#  'FGSL|05',
#  'FGSL|23',
#  'FZNA|18',
#  'FZNA|36',
#  'GCFV|01L',
#  'GCFV|01R',
#  'GCFV|19L',
#  'GCFV|19R',
#  'GCLA|01',
#  'GCLA|19',
#  'GCTS|08',
#  'GCTS|26',
#  'GMTA|17',
#  'GMTA|35',
#  'GVSV|07',
#  'GVSV|25',
#  'HCMK|05',
#  'HECA|16',
#  'HECA|34',
#  'HECW|16',
#  'HECW|34',
#  'HEGN|16',
#  'HEGN|34',
#  'HKKI|07',
#  'HKKI|25',
#  'HKLU|16',
#  'HKLU|34',
#  'HLKF|02',
#  'HLKF|20',
#  'HLLM|11',
#  'HLLM|29',
#  'HSSJ|13',
#  'HSSJ|31',
#  'HSSM|04',
#  'HSSM|22',
#  'HSSS|18',
#  'HSSS|36',
#  'KAUS|17L',
#  'KAUS|17R',
#  'KAUS|35L',
#  'KAUS|35R',
#  'KAVL|16',
#  'KAVL|34',
#  'KBFI|13L',
#  'KBFI|13R',
#  'KBFI|31L',
#  'KBFI|31R',
#  'KBJC|02',
#  'KBJC|11L',
#  'KBJC|11R',
#  'KBJC|20',
#  'KBJC|29L',
#  'KBJC|29R',
#  'KBMC|16',
#  'KBMC|34',
#  'KCLL|10',
#  'KCLL|16',
#  'KCLL|28',
#  'KCLL|34',
#  'KCOE|01',
#  'KCOE|05',
#  'KCOE|19',
#  'KCOE|23',
#  'KCOF|02',
#  'KCOF|20',
#  'KFLL|09L',
#  'KFLL|09R',
#  'KFLL|27L',
#  'KFLL|27R',
#  'KFPR|10L',
#  'KFPR|28R',
#  'KFXE|08',
#  'KFXE|26',
#  'KGED|13',
#  'KGED|31',
#  'KGIF|04',
#  'KGIF|22',
#  'KGTF|16',
#  'KGTF|34',
#  'KHOB|08',
#  'KHOB|26',
#  'KHVR|07',
#  'KHVR|25',
#  'KHWO|09L',
#  'KHWO|09R',
#  'KHWO|18L',
#  'KHWO|18R',
#  'KHWO|27L',
#  'KHWO|27R',
#  'KHWO|36L',
#  'KHWO|36R',
#  'KJOT|12',
#  'KJOT|30',
#  'KLAL|09',
#  'KLAL|27',
#  'KLAS|07L',
#  'KLAS|07R',
#  'KLAS|25L',
#  'KLAS|25R',
#  'KLGB|07L',
#  'KLGB|07R',
#  'KLGB|25L',
#  'KLGB|25R',
#  'KLSE|03',
#  'KLSE|21',
#  'KLWT|07',
#  'KLWT|25',
#  'KMGJ|03',
#  'KMGJ|08',
#  'KMGJ|21']

# %%
x = OAData.loc[(OAData["airport_ident"] == "AGGH"), "le_ident"]

x.to_string().split(" ")
# Out:
# ['10787', '', '', '', '06']

# %%
x = OAData.loc[(OAData["airport_ident"] == row.airportICAO), "le_heading_degT"]

cursor = "le_heading_degT"
OAData.loc[(OAData["airport_ident"] == row.airportICAO), cursor].to_string().split(" ")[4]
# Out:
# '121.0'

# %%
OAData.loc[(OAData["airport_ident"] == "KMGW")]
# Out:
#            id  airport_ref airport_ident  length_ft  width_ft surface  \
# 23153  243373         3682          KMGW     2769.0      75.0     ASP
# 23154  243374         3682          KMGW     5199.0     150.0     ASP
# 23155  355024         3682          KMGW     2769.0      75.0     ASP
#
#        lighted  closed le_ident  le_latitude_deg  le_longitude_deg  \
# 23153        1       0       05        39.638901        -79.917503
# 23154        1       0       18        39.650700        -79.918800
# 23155        0       1        5              NaN               NaN
#
#        le_elevation_ft  le_heading_degT  le_displaced_threshold_ft he_ident  \
# 23153           1241.0             44.9                        NaN       23
# 23154           1236.0            172.4                        NaN       36
# 23155              NaN             45.0                        NaN       23
#
#        he_latitude_deg  he_longitude_deg  he_elevation_ft  he_heading_degT  \
# 23153        39.644299        -79.910500           1241.0            224.9
# 23154        39.636501        -79.916298           1244.0            352.4
# 23155              NaN               NaN              NaN            225.0
#
#        he_displaced_threshold_ft
# 23153                        NaN
# 23154                        NaN
# 23155                        NaN

# %%
OAData.drop[(OAData["id"] == "355024")]

OAData.loc[(OAData["airport_ident"] == "KMGW")]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-e56595f2773c> in <module>
# ----> 1 OAData.drop[(OAData["id"] == "355024")]
#       2
#       3 OAData.loc[(OAData["airport_ident"] == "KMGW")]
#
# TypeError: 'method' object is not subscriptable

# %%
database.loc[(database["airportICAO"] == "KMGW")]
# Out:
#      airportICAO rwyIdent  rwyBearing  rwyTrueBearing  rwySlope  \
# 4618        KMGW       05        54.0       44.975943   0.00000
# 4619        KMGW       18       181.0      172.271215   0.15388
# 4620        KMGW       23       234.0      224.975943   0.00000
# 4621        KMGW       36         1.0      352.271215  -0.15388
#
#       rwyThresElevation  rwyThresCrossHeight  rwyWidth     rwyLon     rwyLat  \
# 4618            382.228               15.400      23.1 -79.917503  39.638901
# 4619            380.688               18.172      46.2 -79.918800  39.650700
# 4620            382.228               15.400      23.1 -79.910500  39.644299
# 4621            383.152               16.016      46.2 -79.916298  39.636501
#
#       ...  gldslpFreq gldslpAngle gldslpIdent  llzLat  llzLon  llzElevation  \
# 4618  ...         NaN         NaN        None     NaN     NaN           NaN
# 4619  ...       108.5    3.001724        IMGW     NaN     NaN           NaN
# 4620  ...         NaN         NaN        None     NaN     NaN           NaN
# 4621  ...         NaN         NaN        None     NaN     NaN           NaN
#
#       llzFreq  llzBearing llzIdent llzCategory
# 4618      NaN         NaN     None        None
# 4619      NaN         NaN     None        None
# 4620      NaN         NaN     None        None
# 4621      NaN         NaN     None        None
#
# [4 rows x 33 columns]

# %%
database.loc[(database["airportICAO"] == "KMGW") & (database["rwyIdent"] == "14L")]
# Out:
# Empty DataFrame
# Columns: [airportICAO, rwyIdent, rwyBearing, rwyTrueBearing, rwySlope, rwyThresElevation, rwyThresCrossHeight, rwyWidth, rwyLon, rwyLat, rwyLength, rwySurface, rwyGlideslopeAngle, ilsLat, ilsLon, ilsElevation, ilsFreq, ilsBearing, ilsIdent, ilsCategory, gldslpLat, gldslpLon, gldslpElevation, gldslpFreq, gldslpAngle, gldslpIdent, llzLat, llzLon, llzElevation, llzFreq, llzBearing, llzIdent, llzCategory]
# Index: []
#
# [0 rows x 33 columns]

# %%
cursor = "he_heading_degT"
identifier = "le_ident"
    
OAData.loc[(OAData["airport_ident"] == "KMGW")]
# Out:
#            id  airport_ref airport_ident  length_ft  width_ft surface  \
# 23145  243373         3682          KMGW     2769.0      75.0     ASP
# 23146  243374         3682          KMGW     5199.0     150.0     ASP
# 23147  355024         3682          KMGW     2769.0      75.0     ASP
#
#        lighted  closed le_ident  le_latitude_deg  le_longitude_deg  \
# 23145        1       0       05        39.638901        -79.917503
# 23146        1       0       18        39.650700        -79.918800
# 23147        0       1        5              NaN               NaN
#
#        le_elevation_ft  le_heading_degT  le_displaced_threshold_ft he_ident  \
# 23145           1241.0             44.9                        NaN       23
# 23146           1236.0            172.4                        NaN       36
# 23147              NaN             45.0                        NaN       23
#
#        he_latitude_deg  he_longitude_deg  he_elevation_ft  he_heading_degT  \
# 23145        39.644299        -79.910500           1241.0            224.9
# 23146        39.636501        -79.916298           1244.0            352.4
# 23147              NaN               NaN              NaN            225.0
#
#        he_displaced_threshold_ft
# 23145                        NaN
# 23146                        NaN
# 23147                        NaN

# %%
OAData.loc[(OAData["airport_ident"] == "BGJN") & ((OAData["le_ident"] == "14L") | (OAData["he_ident"] == "14L"))]
# Out:
#            id  airport_ref airport_ident  length_ft  width_ft surface  \
# 11780  238362           67          AYPY     9022.0     148.0     ASP
#
#        lighted  closed le_ident  le_latitude_deg  le_longitude_deg  \
# 11780        1       0      14L         -9.43087        147.214005
#
#        le_elevation_ft  le_heading_degT  le_displaced_threshold_ft he_ident  \
# 11780            103.0            148.4                        NaN      32R
#
#        he_latitude_deg  he_longitude_deg  he_elevation_ft  he_heading_degT  \
# 11780          -9.4521        147.227005            128.0            328.4
#
#        he_displaced_threshold_ft
# 11780                        NaN
