# %%
import pandas
pandas.set_option('display.max_columns', None)
pandas.set_option('display.max_rows', None)
import sqlite3

connection = sqlite3.connect('D:/Akademik/Semester 7/TA 1/Example 1/airport-develop/airport-develop/resources/database/Airports.db')
query = 'select * from runways'
database = pandas.read_sql_query(query, connection)

# %%
len(database.airportICAO.unique())
# Out:
# 3918

# %%
database.head(10)
# Out:
#   airportICAO rwyIdent  rwyBearing  rwyTrueBearing  rwySlope  \
# 0        AGGH       06        59.0       68.242264 -0.221670
# 1        AGGH       24       239.0      248.242264  0.221670
# 2        ANYN       12       121.0      129.267903 -0.028353
# 3        ANYN       30       301.0      309.267903  0.028353
# 4        AYBK       04        39.0       46.780566 -0.097561
# 5        AYBK       22       219.0      226.780566  0.097561
# 6        AYDU       14       129.0      135.096562  0.043545
# 7        AYDU       32       309.0      315.096562 -0.043545
# 8        AYGN       09        93.0      101.148053 -0.739400
# 9        AYGN       27       273.0      281.148053  0.739400
#
#    rwyThresElevation  rwyThresCrossHeight  rwyWidth      rwyLon     rwyLat  \
# 0              9.240                 15.4    45.584  160.044998  -9.431740
# 1              4.312                 15.4    45.584  160.063995  -9.424260
# ...

# %%
database.to_csv('TUMDatabase.csv')

# %%
data_dict = {s:[] for s in database.columns}
data = pandas.DataFrame(data_dict)
data
# Out:
# Empty DataFrame
# Columns: [airportICAO, rwyIdent, rwyBearing, rwyTrueBearing, rwySlope, rwyThresElevation, rwyThresCrossHeight, rwyWidth, rwyLon, rwyLat, rwyLength, rwySurface, rwyGlideslopeAngle, ilsLat, ilsLon, ilsElevation, ilsFreq, ilsBearing, ilsIdent, ilsCategory, gldslpLat, gldslpLon, gldslpElevation, gldslpFreq, gldslpAngle, gldslpIdent, llzLat, llzLon, llzElevation, llzFreq, llzBearing, llzIdent, llzCategory]
# Index: []

# %%
database.loc[(database["airportICAO"] =="MDBH")]
# Out:
#      airportICAO rwyIdent  rwyBearing  rwyTrueBearing  rwySlope  \
# 6792        MDBH       12       125.0      117.193811       0.0
# 6793        MDBH       30       305.0      297.193811       0.0
#
#       rwyThresElevation  rwyThresCrossHeight  rwyWidth     rwyLon     rwyLat  \
# 6792               3.08                 15.4    45.584 -71.133102  18.257200
# 6793               3.08                 15.4    45.584 -71.108101  18.245001
#
#       rwyLength rwySurface rwyGlideslopeAngle  ilsLat  ilsLon  ilsElevation  \
# 6792    3031.64    Asphalt            Unknown     NaN     NaN           NaN
# 6793    3031.64    Asphalt            Unknown     NaN     NaN           NaN
#
#       ilsFreq  ilsBearing ilsIdent ilsCategory  gldslpLat  gldslpLon  \
# 6792      NaN         NaN     None        None        NaN        NaN
# 6793      NaN         NaN     None        None        NaN        NaN
#
#       gldslpElevation  gldslpFreq  gldslpAngle gldslpIdent  llzLat  llzLon  \
# ...

# %%
database.columns
# Out:
# Index(['airportICAO', 'rwyIdent', 'rwyBearing', 'rwyTrueBearing', 'rwySlope',
#        'rwyThresElevation', 'rwyThresCrossHeight', 'rwyWidth', 'rwyLon',
#        'rwyLat', 'rwyLength', 'rwySurface', 'rwyGlideslopeAngle', 'ilsLat',
#        'ilsLon', 'ilsElevation', 'ilsFreq', 'ilsBearing', 'ilsIdent',
#        'ilsCategory', 'gldslpLat', 'gldslpLon', 'gldslpElevation',
#        'gldslpFreq', 'gldslpAngle', 'gldslpIdent', 'llzLat', 'llzLon',
#        'llzElevation', 'llzFreq', 'llzBearing', 'llzIdent', 'llzCategory'],
#       dtype='object')

# %%
database.loc[(database["airportICAO"] =="WIII")]
# Out:
#       airportICAO rwyIdent  rwyBearing  rwyTrueBearing  rwySlope  \
# 10116        WIII      07L        68.0       68.184077 -0.067733
# 10117        WIII      07R        68.0       67.775903 -0.058294
# 10118        WIII      25L       248.0      247.775903  0.058294
# 10119        WIII      25R       248.0      248.184077  0.067733
#
#        rwyThresElevation  rwyThresCrossHeight  rwyWidth      rwyLon   rwyLat  \
# 10116              8.932               15.708    60.676  106.639000 -6.12090
# 10117             10.472               15.708    60.676  106.643997 -6.14250
# 10118              8.316               15.092    60.676  106.674004 -6.13031
# 10119              6.468               15.400    60.676  106.668999 -6.10896
#
#        rwyLength rwySurface rwyGlideslopeAngle    ilsLat      ilsLon  \
# 10116    3637.79   Concrete            Unknown -6.108114  106.671196
# 10117    3698.46   Concrete            Unknown -6.129364  106.676735
# ...

# %%
#import fastparquet
#import pandas

# %%
database.to_parquet('TUMDatabase.parquet', compression='gzip')

# %%
pandas.read_parquet('TUMDatabase.parquet').head(11)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-9355c4fc588a> in <module>
# ----> 1 pandas.read_parquet('TUMDatabase.parquet').head(11)
#
# ~\anaconda3\lib\site-packages\pandas\io\parquet.py in read_parquet(path, engine, columns, **kwargs)
#     315     """
#     316     impl = get_engine(engine)
# --> 317     return impl.read(path, columns=columns, **kwargs)
#
# ~\anaconda3\lib\site-packages\pandas\io\parquet.py in read(self, path, columns, **kwargs)
#     210             parquet_file = self.api.ParquetFile(path)
#     211
# --> 212         return parquet_file.to_pandas(columns=columns, **kwargs)
#     213
#     214
#
# ~\anaconda3\lib\site-packages\fastparquet\api.py in to_pandas(self, columns, categories, filters, index)
#     399                                     else v[start:start + rg.num_rows])
# ...

# %%
TUMrequestayah = database.head(100)

TUMrequestayah
# Out:
#    airportICAO rwyIdent  rwyBearing  rwyTrueBearing  rwySlope  \
# 0         AGGH       06        59.0       68.242264 -0.221670
# 1         AGGH       24       239.0      248.242264  0.221670
# 2         ANYN       12       121.0      129.267903 -0.028353
# 3         ANYN       30       301.0      309.267903  0.028353
# 4         AYBK       04        39.0       46.780566 -0.097561
# 5         AYBK       22       219.0      226.780566  0.097561
# 6         AYDU       14       129.0      135.096562  0.043545
# 7         AYDU       32       309.0      315.096562 -0.043545
# 8         AYGN       09        93.0      101.148053 -0.739400
# 9         AYGN       27       273.0      281.148053  0.739400
# 10        AYKI       07        70.0       73.307826  0.447870
# 11        AYKI       25       250.0      253.307826 -0.447870
# 12        AYKV       12       120.0      126.050713  0.059335
# 13        AYKV       30       300.0      306.050713 -0.059335
# ...

# %%
TUMrequestayah.to_csv('TUMayah.csv')
